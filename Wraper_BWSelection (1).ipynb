# %% [markdown]
# ## ***Feature Selection-Backward Selection***
#
# Feature Extraction and Data Preparation:
# It loads a dataset from a CSV file (BWSelection.csv).
#
# It prepares the data for modeling by:
# Separating features (X) and the target variable (y).
# Scaling the features using StandardScaler to standardize them.
#
# Model Training and Evaluation:
# It initializes five different classifiers: Decision Tree, Random Forest, SVM, Neural Network (MLP), and K-Nearest Neighbors (KNN).
# It uses stratified k-fold cross-validation to evaluate each classifier's performance, calculating metrics like accuracy, precision, recall, and F1-score.
# It prints these metrics and displays confusion matrices for each classifier.
#
# Model Comparison and Selection:
# It identifies the best-performing classifier based on cross-validation accuracy.
# It displays the top 3 classifiers along with their detailed performance metrics.
#
# ROC Curve Plotting:
# It plots ROC curves for selected classifiers (Decision Tree and Random Forest) to visualize their performance in distinguishing between classes.
# It calculates and displays the Area Under the Curve (AUC) for each ROC curve, indicating the classifier's overall ability to discriminate.
#
# Accuracy Visualization:
# It creates a bar plot to compare the accuracy of all classifiers visually.
# MLPClassifier Loss Curve:
# It initializes an MLPClassifier with specific parameters, including verbose=True to enable the recording of the loss curve during training.
# It trains the MLPClassifier on the data.
# It plots the loss curve, showing how the training loss decreases over iterations (epochs).
#
# Results Interpretation
#
# Metrics: The printed metrics (accuracy, precision, recall, F1-score) provide quantitative measures of each classifier's performance. Higher values generally indicate better performance.
#
# Confusion Matrices: Confusion matrices visualize the classifier's predictions, showing the number of true positives, true negatives, false positives, and false negatives. They help assess the types of errors the classifier is making.
#
# ROC Curves and AUC: ROC curves illustrate the trade-off between true positive rate and false positive rate for different classification thresholds. A higher AUC indicates better overall performance.
#
# Accuracy Bar Plot: This plot provides a visual comparison of the accuracy of all classifiers, making it easy to identify the best-performing one.
#
# MLPClassifier Loss Curve: The loss curve shows how the training loss decreases as the neural network learns. Ideally, you want to see a smooth, decreasing curve, indicating that the model is converging and improving its performance.

# %% [markdown]
# ## Feature extration from feature selection: Selected Feature from Forward Selected Features

# %%
import pandas as pd  # Import pandas for data manipulation
import numpy as np  # Import NumPy for numerical operations
import os  # Import os for directory operations
import re  # Import re for regular expressions

# Define the path to the concatenated feature CSV file
input_directory = '/content/drive/MyDrive/Colab Notebooks/FEDM/CSV Floder/concatenated_data.csv'  # Path to the CSV file

# List of features to extract, including 'Class_Label' as specified
features_to_extract = ['Smoothness', 'Entropy', 'Skewness', 'Class_Label', 'Kurtosis', 'Energy']  # Specify the features of interest

# Read the concatenated CSV file into a DataFrame
df = pd.read_csv(input_directory)  # Read the CSV file into a DataFrame

# Verify that each feature exists in the DataFrame columns
existing_features = [feature for feature in features_to_extract if feature in df.columns]
if not existing_features:
    print("None of the specified features are present in the DataFrame.")
else:
    # Extract only the specified features
    extracted_features = df[existing_features]  # Select only the available specified features

    # Rename the DataFrame's index to the filename (if applicable) and keep only the numerical part
    numerical_filename = re.search(r'\d+', os.path.basename(input_directory))  # Extract numerical part from the filename
    if numerical_filename:  # Check if a number was found
        extracted_features['filename'] = numerical_filename.group()  # Add the numerical part as the filename

    # Define the output file path including filename
    output_file_path = '/content/drive/MyDrive/Colab Notebooks/FEDM/final_dataframe.csv'

    # Save the final DataFrame to a new CSV file
    extracted_features.to_csv(output_file_path, index=False)  # Save the extracted features to a CSV file without the index

    print("Extraction completed and saved to:", output_file_path)  # Print completion message
# Out:
# Extraction completed and saved to: /content/drive/MyDrive/Colab Notebooks/FEDM/final_dataframe.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Classifier-DT, KNN , Random Forest, SVM, NN-MPTL

# %% [markdown]
# ## Step 1: Import necessary libraries and load the dataset

# %%
import warnings  # To handle warnings
from sklearn.exceptions import UndefinedMetricWarning, ConvergenceWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)  # Ignore undefined metric warnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)  # Ignore convergence warnings

import os
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve, auc
)
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, label_binarize
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tqdm import tqdm  # For progress bars

# Load dataset as a DataFrame
csv_file = '/content/drive/MyDrive/Colab Notebooks/FEDM-Atheef_001/CSV Floder/BWSelection.csv'  # Path to the dataset
data = pd.read_csv(csv_file)  # Read CSV file into a DataFrame

# %% [markdown]
# ## Step 2: Prepare data for modeling

# %%
X = data.drop('Class_Label', axis=1)  # Separate features (X) by dropping the target variable
y = data['Class_Label']  # Target variable (y)

# Feature scaling to standardize features
scaler = StandardScaler()  # Initialize the StandardScaler
X_scaled = scaler.fit_transform(X)  # Fit and transform features

# Initialize classifiers for comparison
classifiers = {
    "DecisionTree": DecisionTreeClassifier(random_state=0),
    "RandomForest": RandomForestClassifier(n_estimators=500, max_depth=None, n_jobs=-1, random_state=0),
    "SVM": SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=0),
    "NeuralNetwork": MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000, random_state=0, learning_rate_init=0.0005, alpha=0.001),
    "KNN_2": KNeighborsClassifier(n_neighbors=2)
}

# Custom class labels for confusion matrix
class_labels = sorted(y.unique())  # Get sorted unique class labels for later use

# %% [markdown]
# ### Step 3: Model evaluation and metrics calculation

# %%
# Function to calculate and display metrics
def print_metrics(y_test, y_pred, clf_name):
    cm = confusion_matrix(y_test, y_pred)  # Compute confusion matrix
    accuracy = accuracy_score(y_test, y_pred)  # Calculate accuracy
    precision = precision_score(y_test, y_pred, average="weighted")  # Calculate precision
    sensitivity = recall_score(y_test, y_pred, average="weighted")  # Calculate recall (sensitivity)
    specificity = np.sum(cm.diagonal()) / np.sum(cm)  # Calculate specificity
    f1 = f1_score(y_test, y_pred, average="weighted")  # Calculate F1-Score

    # Print metrics
    print(f"\nMetrics for {clf_name}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Sensitivity (Recall): {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Confusion matrix visualization
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', cbar=False,
                xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'Confusion Matrix - {clf_name}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    return accuracy, precision, sensitivity, specificity, f1

# Stratified K-Fold for balanced cross-validation
n_folds = 10  # Number of folds for cross-validation
cv = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)  # Initialize K-Fold

# Evaluate classifiers using cross-validation
cv_results = {}  # Dictionary to store cross-validation results
best_classifier = {"name": None, "accuracy": 0}  # To keep track of the best classifier

for clf_name, clf in classifiers.items():  # Loop through each classifier
    print(f"\nEvaluating {clf_name} with {n_folds}-fold cross-validation...")

    # Cross-validation scores for different metrics
    accuracy_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='accuracy')
    precision_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='precision_weighted')
    recall_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='recall_weighted')
    f1_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='f1_weighted')

    # Store results
    cv_results[clf_name] = {
        "accuracy": np.mean(accuracy_scores),
        "precision": np.mean(precision_scores),
        "recall": np.mean(recall_scores),
        "f1_score": np.mean(f1_scores)
    }

    # Print cross-validation results for the classifier
    print(f"Cross-Validation Results for {clf_name}:")
    print(f"  Accuracy: {cv_results[clf_name]['accuracy']:.4f}")
    print(f"  Precision: {cv_results[clf_name]['precision']:.4f}")
    print(f"  Recall (Sensitivity): {cv_results[clf_name]['recall']:.4f}")
    print(f"  F1-Score: {cv_results[clf_name]['f1_score']:.4f}\n")

    # Update the best classifier based on accuracy
    if cv_results[clf_name]["accuracy"] > best_classifier["accuracy"]:
        best_classifier = {"name": clf_name, "accuracy": cv_results[clf_name]["accuracy"]}

    # Fit the classifier on the entire dataset for confusion matrix plot
    clf.fit(X_scaled, y)  # Train the classifier
    y_pred = clf.predict(X_scaled)  # Predict on the scaled data
    print_metrics(y, y_pred, clf_name)  # Print metrics and plot confusion matrix

print(f"Best classifier based on cross-validation: {best_classifier['name']} with accuracy {best_classifier['accuracy']:.4f}")
# Out:
# Evaluating DecisionTree with 10-fold cross-validation...
# Cross-Validation Results for DecisionTree:
#   Accuracy: 0.8672
#   Precision: 0.8835
#   Recall (Sensitivity): 0.8672
#   F1-Score: 0.8665
#
#
# Metrics for DecisionTree:
# Accuracy: 0.9980
# Precision: 0.9980
# Sensitivity (Recall): 0.9980
# Specificity: 0.9980
# F1-Score: 0.9980
# Evaluating RandomForest with 10-fold cross-validation...
# Cross-Validation Results for RandomForest:
#   Accuracy: 0.8713
#   Precision: 0.8884
#   Recall (Sensitivity): 0.8713
#   F1-Score: 0.8710
#
#
# Metrics for RandomForest:
# Accuracy: 0.9980
# Precision: 0.9980
# Sensitivity (Recall): 0.9980
# Specificity: 0.9980
# F1-Score: 0.9980
# Evaluating SVM with 10-fold cross-validation...
# Cross-Validation Results for SVM:
#   Accuracy: 0.1240
#   Precision: 0.3101
#   Recall (Sensitivity): 0.1240
#   F1-Score: 0.1047
#
#
# Metrics for SVM:
# Accuracy: 0.1574
# Precision: 0.7242
# Sensitivity (Recall): 0.1574
# Specificity: 0.1574
# F1-Score: 0.1701
# Evaluating NeuralNetwork with 10-fold cross-validation...
# Cross-Validation Results for NeuralNetwork:
#   Accuracy: 0.1873
#   Precision: 0.1967
#   Recall (Sensitivity): 0.1873
#   F1-Score: 0.1768
#
#
# Metrics for NeuralNetwork:
# Accuracy: 0.2909
# Precision: 0.3428
# Sensitivity (Recall): 0.2909
# Specificity: 0.2909
# F1-Score: 0.2858
# Evaluating KNN_2 with 10-fold cross-validation...
# Cross-Validation Results for KNN_2:
#   Accuracy: 0.5000
#   Precision: 0.5109
#   Recall (Sensitivity): 0.5000
#   F1-Score: 0.4642
#
#
# Metrics for KNN_2:
# Accuracy: 0.9673
# Precision: 0.9679
# Sensitivity (Recall): 0.9673
# Specificity: 0.9673
# F1-Score: 0.9673
# Best classifier based on cross-validation: RandomForest with accuracy 0.8713

# %% [markdown]
# ## Step 4: ROC curve plotting and accuracy visualization

# %%
# Sort classifiers based on mean accuracy in descending order
sorted_classifiers = sorted(cv_results.items(), key=lambda x: x[1]['accuracy'], reverse=True)

# Display the top 3 classifiers
print("\nTop 3 Classifiers based on Mean Accuracy:")
for i, (clf_name, scores) in enumerate(sorted_classifiers[:3], start=1):
    print(f"\nRank {i}: {clf_name}")
    print(f"  Accuracy: {scores['accuracy']:.4f}")
    print(f"  Precision: {scores['precision']:.4f}")
    print(f"  Recall (Sensitivity): {scores['recall']:.4f}")
    print(f"  F1-Score: {scores['f1_score']:.4f}")

# Plotting ROC curves for selected classifiers
selected_classifiers = {
    "DecisionTree": classifiers["DecisionTree"],
    "RandomForest": classifiers["RandomForest"]
}

# Number of folds for cross-validation
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)  # Initialize Stratified K-Fold

for clf_name, clf in selected_classifiers.items():
    plt.figure(figsize=(10, 8))  # Initialize figure for ROC curve
    plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")  # Baseline line for random guessing
    plt.title(f'ROC Curve for {clf_name} with {n_folds}-Fold Cross-Validation')  # Title for the plot
    plt.xlabel('False Positive Rate')  # X-axis label
    plt.ylabel('True Positive Rate')  # Y-axis label

    mean_fpr = np.linspace(0, 1, 100)  # Define mean false positive rate
    tprs, aucs = [], []  # Initialize lists for true positive rates and AUC values

    # Stratified K-Folds cross-validation for ROC curve
    for train_index, test_index in skf.split(X_scaled, y):
        X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]  # Split data
        y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]  # Split labels

        # Fit the classifier on the training fold
        clf.fit(X_train_fold, y_train_fold)  # Train the classifier on the training data

        # Calculate ROC curve and AUC
        if hasattr(clf, "predict_proba"):  # If the classifier has predict_proba method
            y_proba = clf.predict_proba(X_test_fold)  # Get predicted probabilities
            if len(np.unique(y)) == 2:  # Binary classification
                fpr, tpr, _ = roc_curve(y_test_fold, y_proba[:, 1])  # Calculate ROC for positive class
            else:  # Multi-class classification
                y_test_binarized = label_binarize(y_test_fold, classes=np.unique(y))  # Binarize labels
                fpr, tpr, _ = roc_curve(y_test_binarized.ravel(), y_proba.ravel())  # Calculate ROC for multi-class
        elif hasattr(clf, "decision_function"):  # If the classifier has decision_function method
            y_score = clf.decision_function(X_test_fold)  # Get decision scores
            if len(np.unique(y)) == 2:  # Binary classification
                fpr, tpr, _ = roc_curve(y_test_fold, y_score)  # Calculate ROC for binary
            else:  # Multi-class classification
                y_test_binarized = label_binarize(y_test_fold, classes=np.unique(y))  # Binarize labels
                fpr, tpr, _ = roc_curve(y_test_binarized.ravel(), y_score.ravel())  # Calculate ROC for multi-class
        else:
            print(f"{clf_name} does not support ROC plotting.")  # Warning for unsupported classifiers
            continue

        # Interpolated TPR for consistent mean ROC curve
        interp_tpr = np.interp(mean_fpr, fpr, tpr)  # Interpolate TPR
        interp_tpr[0] = 0.0  # Ensure the first point is 0
        tprs.append(interp_tpr)  # Append interpolated TPR
        aucs.append(auc(fpr, tpr))  # Append AUC

        # Individual ROC curve for each fold
        plt.plot(fpr, tpr, alpha=0.3)  # Plot individual ROC curves

    # Plot mean ROC curve across folds
    mean_tpr = np.mean(tprs, axis=0)  # Calculate mean TPR
    mean_tpr[-1] = 1.0  # Ensure end of TPR is 1.0
    mean_auc = auc(mean_fpr, mean_tpr)  # Calculate mean AUC
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean AUC = {mean_auc:.4f}', lw=2)  # Plot mean ROC curve

    # Finalize plot with legend and axis limits
    plt.legend(loc="lower right")  # Add legend
    plt.xlim([0.0, 1.0])  # Set x-axis limits
    plt.ylim([0.0, 1.05])  # Set y-axis limits
    plt.show()  # Show the plot

# Output the name and accuracy of the best-performing classifier
print("\nBest Classifier Results:")
print(f"Classifier: {best_classifier['name']}")
print(f"Accuracy: {best_classifier['accuracy']:.4f}")
# Out:
# Top 3 Classifiers based on Mean Accuracy:
#
# Rank 1: RandomForest
#   Accuracy: 0.8713
#   Precision: 0.8884
#   Recall (Sensitivity): 0.8713
#   F1-Score: 0.8710
#
# Rank 2: DecisionTree
#   Accuracy: 0.8672
#   Precision: 0.8835
#   Recall (Sensitivity): 0.8672
#   F1-Score: 0.8665
#
# Rank 3: KNN_2
#   Accuracy: 0.5000
#   Precision: 0.5109
#   Recall (Sensitivity): 0.5000
#   F1-Score: 0.4642
# Best Classifier Results:
# Classifier: RandomForest
# Accuracy: 0.8713

# %% [markdown]
# ### Plotting Accuracy Bar Plot for Each Classifier

# %%
# Plotting Accuracy Bar Plot for Each Classifier

# Extract classifier names and their corresponding accuracy scores
classifier_names = list(cv_results.keys())
accuracy_scores = [cv_results[clf]["accuracy"] for clf in classifier_names]

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=accuracy_scores, y=classifier_names, hue=classifier_names, palette="viridis", dodge=False, legend=False)

# Customize plot
plt.title("Accuracy of Each Classifier")
plt.xlabel("Mean Accuracy (Cross-Validated)")
plt.ylabel("Classifier")
plt.xlim(0, 1)  # Set limit to 1 since accuracy ranges from 0 to 1
plt.show()

# %% [markdown]
# ## Initialize MLPClassifier with parameters that ensure the loss curve is recorded

# %%
# Initialize MLPClassifier with parameters that ensure the loss curve is recorded
mlp_clf = MLPClassifier(
    hidden_layer_sizes=(100, 50),
    max_iter=1000,
    random_state=0,
    learning_rate_init=0.0005,
    alpha=0.001,
    verbose=True  # Enables printing progress, including the loss curve tracking
)

# Fit the classifier on the scaled data
mlp_clf.fit(X_scaled, y)

# Plot the loss curve
plt.figure(figsize=(10, 6))
plt.plot(mlp_clf.loss_curve_, label="Training Loss")
plt.title("MLPClassifier Training Loss Curve")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Iteration 1, loss = 2.81373156
# Iteration 2, loss = 2.79663997
# Iteration 3, loss = 2.78500658
# Iteration 4, loss = 2.77464135
# Iteration 5, loss = 2.76569901
# Iteration 6, loss = 2.75788305
# Iteration 7, loss = 2.75136205
# Iteration 8, loss = 2.74511910
# Iteration 9, loss = 2.73955378
# Iteration 10, loss = 2.73458949
# Iteration 11, loss = 2.72976857
# Iteration 12, loss = 2.72540768
# Iteration 13, loss = 2.72134066
# Iteration 14, loss = 2.71743629
# Iteration 15, loss = 2.71370890
# Iteration 16, loss = 2.71068302
# Iteration 17, loss = 2.70749726
# Iteration 18, loss = 2.70497327
# Iteration 19, loss = 2.70201068
# Iteration 20, loss = 2.69957328
# Iteration 21, loss = 2.69735424
# Iteration 22, loss = 2.69491161
# Iteration 23, loss = 2.69238536
# Iteration 24, loss = 2.69010767
# Iteration 25, loss = 2.68800841
# Iteration 26, loss = 2.68575550
# Iteration 27, loss = 2.68372589
# Iteration 28, loss = 2.68152405
# Iteration 29, loss = 2.67973470
# Iteration 30, loss = 2.67759587
# Iteration 31, loss = 2.67549314
# Iteration 32, loss = 2.67339370
# Iteration 33, loss = 2.67129979
# Iteration 34, loss = 2.66974391
# Iteration 35, loss = 2.66780890
# Iteration 36, loss = 2.66576436
# Iteration 37, loss = 2.66429790
# Iteration 38, loss = 2.66265010
# Iteration 39, loss = 2.66103256
# Iteration 40, loss = 2.65915448
# Iteration 41, loss = 2.65727669
# Iteration 42, loss = 2.65584404
# Iteration 43, loss = 2.65382663
# Iteration 44, loss = 2.65222313
# Iteration 45, loss = 2.65096600
# Iteration 46, loss = 2.64904486
# Iteration 47, loss = 2.64748160
# Iteration 48, loss = 2.64574727
# Iteration 49, loss = 2.64415926
# Iteration 50, loss = 2.64259514
# Iteration 51, loss = 2.64067584
# Iteration 52, loss = 2.63939657
# Iteration 53, loss = 2.63782955
# Iteration 54, loss = 2.63647784
# Iteration 55, loss = 2.63492341
# Iteration 56, loss = 2.63324999
# Iteration 57, loss = 2.63181963
# Iteration 58, loss = 2.63029897
# Iteration 59, loss = 2.62894484
# Iteration 60, loss = 2.62745533
# Iteration 61, loss = 2.62596876
# Iteration 62, loss = 2.62484352
# Iteration 63, loss = 2.62308237
# Iteration 64, loss = 2.62166653
# Iteration 65, loss = 2.62014758
# Iteration 66, loss = 2.61881848
# Iteration 67, loss = 2.61763811
# Iteration 68, loss = 2.61619195
# Iteration 69, loss = 2.61471464
# Iteration 70, loss = 2.61331299
# Iteration 71, loss = 2.61174071
# Iteration 72, loss = 2.61040939
# Iteration 73, loss = 2.60900799
# Iteration 74, loss = 2.60768054
# Iteration 75, loss = 2.60633231
# Iteration 76, loss = 2.60469172
# Iteration 77, loss = 2.60362427
# Iteration 78, loss = 2.60259444
# Iteration 79, loss = 2.60069496
# Iteration 80, loss = 2.59971516
# Iteration 81, loss = 2.59844762
# Iteration 82, loss = 2.59797165
# Iteration 83, loss = 2.59653213
# Iteration 84, loss = 2.59479759
# Iteration 85, loss = 2.59319202
# Iteration 86, loss = 2.59202735
# Iteration 87, loss = 2.59106955
# Iteration 88, loss = 2.58959092
# Iteration 89, loss = 2.58843995
# Iteration 90, loss = 2.58692534
# Iteration 91, loss = 2.58621794
# Iteration 92, loss = 2.58473742
# Iteration 93, loss = 2.58331913
# Iteration 94, loss = 2.58205820
# Iteration 95, loss = 2.58076870
# Iteration 96, loss = 2.57982168
# Iteration 97, loss = 2.57835206
# Iteration 98, loss = 2.57735475
# Iteration 99, loss = 2.57618596
# Iteration 100, loss = 2.57540364
# Iteration 101, loss = 2.57404376
# Iteration 102, loss = 2.57277850
# Iteration 103, loss = 2.57186818
# Iteration 104, loss = 2.57063599
# Iteration 105, loss = 2.56936803
# Iteration 106, loss = 2.56859695
# Iteration 107, loss = 2.56778912
# Iteration 108, loss = 2.56661854
# Iteration 109, loss = 2.56509183
# Iteration 110, loss = 2.56392232
# Iteration 111, loss = 2.56278602
# Iteration 112, loss = 2.56187397
# Iteration 113, loss = 2.56076067
# Iteration 114, loss = 2.56014999
# Iteration 115, loss = 2.55902187
# Iteration 116, loss = 2.55766549
# Iteration 117, loss = 2.55674570
# Iteration 118, loss = 2.55565534
# Iteration 119, loss = 2.55472943
# Iteration 120, loss = 2.55376234
# Iteration 121, loss = 2.55300519
# Iteration 122, loss = 2.55174389
# Iteration 123, loss = 2.55058882
# Iteration 124, loss = 2.54964666
# Iteration 125, loss = 2.54881286
# Iteration 126, loss = 2.54753662
# Iteration 127, loss = 2.54721340
# Iteration 128, loss = 2.54599734
# Iteration 129, loss = 2.54492572
# Iteration 130, loss = 2.54438007
# Iteration 131, loss = 2.54290651
# Iteration 132, loss = 2.54217807
# Iteration 133, loss = 2.54126264
# Iteration 134, loss = 2.54008964
# Iteration 135, loss = 2.53953031
# Iteration 136, loss = 2.53828360
# Iteration 137, loss = 2.53764744
# Iteration 138, loss = 2.53681937
# Iteration 139, loss = 2.53599040
# Iteration 140, loss = 2.53494152
# Iteration 141, loss = 2.53403185
# Iteration 142, loss = 2.53331813
# Iteration 143, loss = 2.53272563
# Iteration 144, loss = 2.53176247
# Iteration 145, loss = 2.53098190
# Iteration 146, loss = 2.53023486
# Iteration 147, loss = 2.52915200
# Iteration 148, loss = 2.52829712
# Iteration 149, loss = 2.52773392
# Iteration 150, loss = 2.52668138
# Iteration 151, loss = 2.52578361
# Iteration 152, loss = 2.52496166
# Iteration 153, loss = 2.52405634
# Iteration 154, loss = 2.52355439
# Iteration 155, loss = 2.52243170
# Iteration 156, loss = 2.52236731
# Iteration 157, loss = 2.52115639
# Iteration 158, loss = 2.52008608
# Iteration 159, loss = 2.51950887
# Iteration 160, loss = 2.51860807
# Iteration 161, loss = 2.51826019
# Iteration 162, loss = 2.51686977
# Iteration 163, loss = 2.51584618
# Iteration 164, loss = 2.51566119
# Iteration 165, loss = 2.51485379
# Iteration 166, loss = 2.51455007
# Iteration 167, loss = 2.51341400
# Iteration 168, loss = 2.51272070
# Iteration 169, loss = 2.51196132
# Iteration 170, loss = 2.51129904
# Iteration 171, loss = 2.51048499
# Iteration 172, loss = 2.50994078
# Iteration 173, loss = 2.50931258
# Iteration 174, loss = 2.50810274
# Iteration 175, loss = 2.50793847
# Iteration 176, loss = 2.50684452
# Iteration 177, loss = 2.50579445
# Iteration 178, loss = 2.50508537
# Iteration 179, loss = 2.50446806
# Iteration 180, loss = 2.50381294
# Iteration 181, loss = 2.50287252
# Iteration 182, loss = 2.50298753
# Iteration 183, loss = 2.50207160
# Iteration 184, loss = 2.50146538
# Iteration 185, loss = 2.50059007
# Iteration 186, loss = 2.49983760
# Iteration 187, loss = 2.49928480
# Iteration 188, loss = 2.49915175
# Iteration 189, loss = 2.49786531
# Iteration 190, loss = 2.49741757
# Iteration 191, loss = 2.49660017
# Iteration 192, loss = 2.49655705
# Iteration 193, loss = 2.49575782
# Iteration 194, loss = 2.49455687
# Iteration 195, loss = 2.49467613
# Iteration 196, loss = 2.49329958
# Iteration 197, loss = 2.49284612
# Iteration 198, loss = 2.49244507
# Iteration 199, loss = 2.49231892
# Iteration 200, loss = 2.49106371
# Iteration 201, loss = 2.49016770
# Iteration 202, loss = 2.48950288
# Iteration 203, loss = 2.48947119
# Iteration 204, loss = 2.48883647
# Iteration 205, loss = 2.48751876
# Iteration 206, loss = 2.48753725
# Iteration 207, loss = 2.48627528
# Iteration 208, loss = 2.48623620
# Iteration 209, loss = 2.48582028
# Iteration 210, loss = 2.48467860
# Iteration 211, loss = 2.48388246
# Iteration 212, loss = 2.48364966
# Iteration 213, loss = 2.48356948
# Iteration 214, loss = 2.48262081
# Iteration 215, loss = 2.48202698
# Iteration 216, loss = 2.48149839
# Iteration 217, loss = 2.48102558
# Iteration 218, loss = 2.47999075
# Iteration 219, loss = 2.47964486
# Iteration 220, loss = 2.47973664
# Iteration 221, loss = 2.47852791
# Iteration 222, loss = 2.47820413
# Iteration 223, loss = 2.47736796
# Iteration 224, loss = 2.47686821
# Iteration 225, loss = 2.47625357
# Iteration 226, loss = 2.47592608
# Iteration 227, loss = 2.47579547
# Iteration 228, loss = 2.47450782
# Iteration 229, loss = 2.47408118
# Iteration 230, loss = 2.47336298
# Iteration 231, loss = 2.47291220
# Iteration 232, loss = 2.47280382
# Iteration 233, loss = 2.47198815
# Iteration 234, loss = 2.47163856
# Iteration 235, loss = 2.47087885
# Iteration 236, loss = 2.47010377
# Iteration 237, loss = 2.46949879
# Iteration 238, loss = 2.46878762
# Iteration 239, loss = 2.46860098
# Iteration 240, loss = 2.46837946
# Iteration 241, loss = 2.46787489
# Iteration 242, loss = 2.46661623
# Iteration 243, loss = 2.46643807
# Iteration 244, loss = 2.46570443
# Iteration 245, loss = 2.46539430
# Iteration 246, loss = 2.46491036
# Iteration 247, loss = 2.46399523
# Iteration 248, loss = 2.46404082
# Iteration 249, loss = 2.46337083
# Iteration 250, loss = 2.46239706
# Iteration 251, loss = 2.46259109
# Iteration 252, loss = 2.46171033
# Iteration 253, loss = 2.46072852
# Iteration 254, loss = 2.46033622
# Iteration 255, loss = 2.46004548
# Iteration 256, loss = 2.45952748
# Iteration 257, loss = 2.45873710
# Iteration 258, loss = 2.45818773
# Iteration 259, loss = 2.45802842
# Iteration 260, loss = 2.45695577
# Iteration 261, loss = 2.45686681
# Iteration 262, loss = 2.45667832
# Iteration 263, loss = 2.45607755
# Iteration 264, loss = 2.45539936
# Iteration 265, loss = 2.45465516
# Iteration 266, loss = 2.45427003
# Iteration 267, loss = 2.45344681
# Iteration 268, loss = 2.45332558
# Iteration 269, loss = 2.45276257
# Iteration 270, loss = 2.45208848
# Iteration 271, loss = 2.45225089
# Iteration 272, loss = 2.45104207
# Iteration 273, loss = 2.45075767
# Iteration 274, loss = 2.45039120
# Iteration 275, loss = 2.44944570
# Iteration 276, loss = 2.44911535
# Iteration 277, loss = 2.44862130
# Iteration 278, loss = 2.44813013
# Iteration 279, loss = 2.44789331
# Iteration 280, loss = 2.44694833
# Iteration 281, loss = 2.44655262
# Iteration 282, loss = 2.44633374
# Iteration 283, loss = 2.44552325
# Iteration 284, loss = 2.44541465
# Iteration 285, loss = 2.44448341
# Iteration 286, loss = 2.44389018
# Iteration 287, loss = 2.44357040
# Iteration 288, loss = 2.44344125
# Iteration 289, loss = 2.44271836
# Iteration 290, loss = 2.44205375
# Iteration 291, loss = 2.44184188
# Iteration 292, loss = 2.44147833
# Iteration 293, loss = 2.44081651
# Iteration 294, loss = 2.44051742
# Iteration 295, loss = 2.44034729
# Iteration 296, loss = 2.43897961
# Iteration 297, loss = 2.43889191
# Iteration 298, loss = 2.43834386
# Iteration 299, loss = 2.43802425
# Iteration 300, loss = 2.43717921
# Iteration 301, loss = 2.43701455
# Iteration 302, loss = 2.43625576
# Iteration 303, loss = 2.43607456
# Iteration 304, loss = 2.43536037
# Iteration 305, loss = 2.43516785
# Iteration 306, loss = 2.43452628
# Iteration 307, loss = 2.43390046
# Iteration 308, loss = 2.43381660
# Iteration 309, loss = 2.43289039
# Iteration 310, loss = 2.43310514
# Iteration 311, loss = 2.43227980
# Iteration 312, loss = 2.43206739
# Iteration 313, loss = 2.43146666
# Iteration 314, loss = 2.43073525
# Iteration 315, loss = 2.43030338
# Iteration 316, loss = 2.43003033
# Iteration 317, loss = 2.42937563
# Iteration 318, loss = 2.42885976
# Iteration 319, loss = 2.42850551
# Iteration 320, loss = 2.42845914
# Iteration 321, loss = 2.42779782
# Iteration 322, loss = 2.42760614
# Iteration 323, loss = 2.42720298
# Iteration 324, loss = 2.42612209
# Iteration 325, loss = 2.42550453
# Iteration 326, loss = 2.42494578
# Iteration 327, loss = 2.42459163
# Iteration 328, loss = 2.42421906
# Iteration 329, loss = 2.42371123
# Iteration 330, loss = 2.42355397
# Iteration 331, loss = 2.42293542
# Iteration 332, loss = 2.42236619
# Iteration 333, loss = 2.42238647
# Iteration 334, loss = 2.42164142
# Iteration 335, loss = 2.42140058
# Iteration 336, loss = 2.42124156
# Iteration 337, loss = 2.42093860
# Iteration 338, loss = 2.42088446
# Iteration 339, loss = 2.41919125
# Iteration 340, loss = 2.41935080
# Iteration 341, loss = 2.41914166
# Iteration 342, loss = 2.41833551
# Iteration 343, loss = 2.41783573
# Iteration 344, loss = 2.41734971
# Iteration 345, loss = 2.41727861
# Iteration 346, loss = 2.41727702
# Iteration 347, loss = 2.41643544
# Iteration 348, loss = 2.41571381
# Iteration 349, loss = 2.41544651
# Iteration 350, loss = 2.41545924
# Iteration 351, loss = 2.41470565
# Iteration 352, loss = 2.41374840
# Iteration 353, loss = 2.41371693
# Iteration 354, loss = 2.41397220
# Iteration 355, loss = 2.41317470
# Iteration 356, loss = 2.41204097
# Iteration 357, loss = 2.41230295
# Iteration 358, loss = 2.41153967
# Iteration 359, loss = 2.41150317
# Iteration 360, loss = 2.41170369
# Iteration 361, loss = 2.41065292
# Iteration 362, loss = 2.41008266
# Iteration 363, loss = 2.40941293
# Iteration 364, loss = 2.40963573
# Iteration 365, loss = 2.40904030
# Iteration 366, loss = 2.40823260
# Iteration 367, loss = 2.40765616
# Iteration 368, loss = 2.40731924
# Iteration 369, loss = 2.40674859
# Iteration 370, loss = 2.40672232
# Iteration 371, loss = 2.40658119
# Iteration 372, loss = 2.40640799
# Iteration 373, loss = 2.40538920
# Iteration 374, loss = 2.40500498
# Iteration 375, loss = 2.40478144
# Iteration 376, loss = 2.40440248
# Iteration 377, loss = 2.40336454
# Iteration 378, loss = 2.40351488
# Iteration 379, loss = 2.40288082
# Iteration 380, loss = 2.40257170
# Iteration 381, loss = 2.40262317
# Iteration 382, loss = 2.40183819
# Iteration 383, loss = 2.40124009
# Iteration 384, loss = 2.40088023
# Iteration 385, loss = 2.40062791
# Iteration 386, loss = 2.40041283
# Iteration 387, loss = 2.40018023
# Iteration 388, loss = 2.39928576
# Iteration 389, loss = 2.39925705
# Iteration 390, loss = 2.39863977
# Iteration 391, loss = 2.39830179
# Iteration 392, loss = 2.39807320
# Iteration 393, loss = 2.39767153
# Iteration 394, loss = 2.39721046
# Iteration 395, loss = 2.39667934
# Iteration 396, loss = 2.39683452
# Iteration 397, loss = 2.39617066
# Iteration 398, loss = 2.39510511
# Iteration 399, loss = 2.39537305
# Iteration 400, loss = 2.39515713
# Iteration 401, loss = 2.39442963
# Iteration 402, loss = 2.39387143
# Iteration 403, loss = 2.39341132
# Iteration 404, loss = 2.39310187
# Iteration 405, loss = 2.39316225
# Iteration 406, loss = 2.39224700
# Iteration 407, loss = 2.39232297
# Iteration 408, loss = 2.39175818
# Iteration 409, loss = 2.39118712
# Iteration 410, loss = 2.39130142
# Iteration 411, loss = 2.39077517
# Iteration 412, loss = 2.39087016
# Iteration 413, loss = 2.38989882
# Iteration 414, loss = 2.38917645
# Iteration 415, loss = 2.38880693
# Iteration 416, loss = 2.38826956
# Iteration 417, loss = 2.38827863
# Iteration 418, loss = 2.38795361
# Iteration 419, loss = 2.38716498
# Iteration 420, loss = 2.38681392
# Iteration 421, loss = 2.38660034
# Iteration 422, loss = 2.38606984
# Iteration 423, loss = 2.38591457
# Iteration 424, loss = 2.38503948
# Iteration 425, loss = 2.38474371
# Iteration 426, loss = 2.38434826
# Iteration 427, loss = 2.38428314
# Iteration 428, loss = 2.38377316
# Iteration 429, loss = 2.38318310
# Iteration 430, loss = 2.38255752
# Iteration 431, loss = 2.38215904
# Iteration 432, loss = 2.38183595
# Iteration 433, loss = 2.38239016
# Iteration 434, loss = 2.38157048
# Iteration 435, loss = 2.38109331
# Iteration 436, loss = 2.38121319
# Iteration 437, loss = 2.37991065
# Iteration 438, loss = 2.38001931
# Iteration 439, loss = 2.38012158
# Iteration 440, loss = 2.37944117
# Iteration 441, loss = 2.37854853
# Iteration 442, loss = 2.37842866
# Iteration 443, loss = 2.37809913
# Iteration 444, loss = 2.37755973
# Iteration 445, loss = 2.37718505
# Iteration 446, loss = 2.37756061
# Iteration 447, loss = 2.37641659
# Iteration 448, loss = 2.37650253
# Iteration 449, loss = 2.37572429
# Iteration 450, loss = 2.37529368
# Iteration 451, loss = 2.37517049
# Iteration 452, loss = 2.37453703
# Iteration 453, loss = 2.37403289
# Iteration 454, loss = 2.37399658
# Iteration 455, loss = 2.37406395
# Iteration 456, loss = 2.37291105
# Iteration 457, loss = 2.37249942
# Iteration 458, loss = 2.37255100
# Iteration 459, loss = 2.37178033
# Iteration 460, loss = 2.37213179
# Iteration 461, loss = 2.37139379
# Iteration 462, loss = 2.37121292
# Iteration 463, loss = 2.37079395
# Iteration 464, loss = 2.37049753
# Iteration 465, loss = 2.36965996
# Iteration 466, loss = 2.36933151
# Iteration 467, loss = 2.36937358
# Iteration 468, loss = 2.36875738
# Iteration 469, loss = 2.36898402
# Iteration 470, loss = 2.36809959
# Iteration 471, loss = 2.36803414
# Iteration 472, loss = 2.36764925
# Iteration 473, loss = 2.36689888
# Iteration 474, loss = 2.36634251
# Iteration 475, loss = 2.36567652
# Iteration 476, loss = 2.36570976
# Iteration 477, loss = 2.36564521
# Iteration 478, loss = 2.36547604
# Iteration 479, loss = 2.36488686
# Iteration 480, loss = 2.36443483
# Iteration 481, loss = 2.36451206
# Iteration 482, loss = 2.36415722
# Iteration 483, loss = 2.36307550
# Iteration 484, loss = 2.36299033
# Iteration 485, loss = 2.36214502
# Iteration 486, loss = 2.36208355
# Iteration 487, loss = 2.36218631
# Iteration 488, loss = 2.36156953
# Iteration 489, loss = 2.36128218
# Iteration 490, loss = 2.36129755
# Iteration 491, loss = 2.36045493
# Iteration 492, loss = 2.36049266
# Iteration 493, loss = 2.36012094
# Iteration 494, loss = 2.35977313
# Iteration 495, loss = 2.35854045
# Iteration 496, loss = 2.35859026
# Iteration 497, loss = 2.35821104
# Iteration 498, loss = 2.35789904
# Iteration 499, loss = 2.35797214
# Iteration 500, loss = 2.35717440
# Iteration 501, loss = 2.35700365
# Iteration 502, loss = 2.35665675
# Iteration 503, loss = 2.35592060
# Iteration 504, loss = 2.35581361
# Iteration 505, loss = 2.35535189
# Iteration 506, loss = 2.35512662
# Iteration 507, loss = 2.35503903
# Iteration 508, loss = 2.35436167
# Iteration 509, loss = 2.35431241
# Iteration 510, loss = 2.35331020
# Iteration 511, loss = 2.35349820
# Iteration 512, loss = 2.35297790
# Iteration 513, loss = 2.35269008
# Iteration 514, loss = 2.35193152
# Iteration 515, loss = 2.35157725
# Iteration 516, loss = 2.35189539
# Iteration 517, loss = 2.35166550
# Iteration 518, loss = 2.35082608
# Iteration 519, loss = 2.35023908
# Iteration 520, loss = 2.35062199
# Iteration 521, loss = 2.35029493
# Iteration 522, loss = 2.34924142
# Iteration 523, loss = 2.34927890
# Iteration 524, loss = 2.34844968
# Iteration 525, loss = 2.34865656
# Iteration 526, loss = 2.34840558
# Iteration 527, loss = 2.34730453
# Iteration 528, loss = 2.34764521
# Iteration 529, loss = 2.34750980
# Iteration 530, loss = 2.34741647
# Iteration 531, loss = 2.34642098
# Iteration 532, loss = 2.34604262
# Iteration 533, loss = 2.34552186
# Iteration 534, loss = 2.34532207
# Iteration 535, loss = 2.34550596
# Iteration 536, loss = 2.34522242
# Iteration 537, loss = 2.34429666
# Iteration 538, loss = 2.34390099
# Iteration 539, loss = 2.34384275
# Iteration 540, loss = 2.34328285
# Iteration 541, loss = 2.34315435
# Iteration 542, loss = 2.34287401
# Iteration 543, loss = 2.34202688
# Iteration 544, loss = 2.34208460
# Iteration 545, loss = 2.34226179
# Iteration 546, loss = 2.34156124
# Iteration 547, loss = 2.34057754
# Iteration 548, loss = 2.34078280
# Iteration 549, loss = 2.34036040
# Iteration 550, loss = 2.33949516
# Iteration 551, loss = 2.33925458
# Iteration 552, loss = 2.33935502
# Iteration 553, loss = 2.33849302
# Iteration 554, loss = 2.33875614
# Iteration 555, loss = 2.33825683
# Iteration 556, loss = 2.33764232
# Iteration 557, loss = 2.33670365
# Iteration 558, loss = 2.33662009
# Iteration 559, loss = 2.33633607
# Iteration 560, loss = 2.33643598
# Iteration 561, loss = 2.33622315
# Iteration 562, loss = 2.33623729
# Iteration 563, loss = 2.33527653
# Iteration 564, loss = 2.33473227
# Iteration 565, loss = 2.33496183
# Iteration 566, loss = 2.33390244
# Iteration 567, loss = 2.33396974
# Iteration 568, loss = 2.33368202
# Iteration 569, loss = 2.33410192
# Iteration 570, loss = 2.33261953
# Iteration 571, loss = 2.33248659
# Iteration 572, loss = 2.33236064
# Iteration 573, loss = 2.33220373
# Iteration 574, loss = 2.33164624
# Iteration 575, loss = 2.33157285
# Iteration 576, loss = 2.33108670
# Iteration 577, loss = 2.33058168
# Iteration 578, loss = 2.33014273
# Iteration 579, loss = 2.33049819
# Iteration 580, loss = 2.32935185
# Iteration 581, loss = 2.32939160
# Iteration 582, loss = 2.32918690
# Iteration 583, loss = 2.32906377
# Iteration 584, loss = 2.32827456
# Iteration 585, loss = 2.32765181
# Iteration 586, loss = 2.32865866
# Iteration 587, loss = 2.32732484
# Iteration 588, loss = 2.32719390
# Iteration 589, loss = 2.32647473
# Iteration 590, loss = 2.32591593
# Iteration 591, loss = 2.32542393
# Iteration 592, loss = 2.32537781
# Iteration 593, loss = 2.32542373
# Iteration 594, loss = 2.32456328
# Iteration 595, loss = 2.32460280
# Iteration 596, loss = 2.32433694
# Iteration 597, loss = 2.32359098
# Iteration 598, loss = 2.32418944
# Iteration 599, loss = 2.32351729
# Iteration 600, loss = 2.32331450
# Iteration 601, loss = 2.32240145
# Iteration 602, loss = 2.32234660
# Iteration 603, loss = 2.32195948
# Iteration 604, loss = 2.32155771
# Iteration 605, loss = 2.32171331
# Iteration 606, loss = 2.32062498
# Iteration 607, loss = 2.32121039
# Iteration 608, loss = 2.32059711
# Iteration 609, loss = 2.31930018
# Iteration 610, loss = 2.31989624
# Iteration 611, loss = 2.31920023
# Iteration 612, loss = 2.31847020
# Iteration 613, loss = 2.31837842
# Iteration 614, loss = 2.31815681
# Iteration 615, loss = 2.31735643
# Iteration 616, loss = 2.31795017
# Iteration 617, loss = 2.31722208
# Iteration 618, loss = 2.31845814
# Iteration 619, loss = 2.31671778
# Iteration 620, loss = 2.31664870
# Iteration 621, loss = 2.31595437
# Iteration 622, loss = 2.31528053
# Iteration 623, loss = 2.31600116
# Iteration 624, loss = 2.31482185
# Iteration 625, loss = 2.31492950
# Iteration 626, loss = 2.31426381
# Iteration 627, loss = 2.31359349
# Iteration 628, loss = 2.31380983
# Iteration 629, loss = 2.31278127
# Iteration 630, loss = 2.31297693
# Iteration 631, loss = 2.31241437
# Iteration 632, loss = 2.31209296
# Iteration 633, loss = 2.31190903
# Iteration 634, loss = 2.31170534
# Iteration 635, loss = 2.31109108
# Iteration 636, loss = 2.31136255
# Iteration 637, loss = 2.31056276
# Iteration 638, loss = 2.31065507
# Iteration 639, loss = 2.31057226
# Iteration 640, loss = 2.31013382
# Iteration 641, loss = 2.30946250
# Iteration 642, loss = 2.30895528
# Iteration 643, loss = 2.30859742
# Iteration 644, loss = 2.30943892
# Iteration 645, loss = 2.30761585
# Iteration 646, loss = 2.30880299
# Iteration 647, loss = 2.30822834
# Iteration 648, loss = 2.30754882
# Iteration 649, loss = 2.30752174
# Iteration 650, loss = 2.30667654
# Iteration 651, loss = 2.30640779
# Iteration 652, loss = 2.30606128
# Iteration 653, loss = 2.30564759
# Iteration 654, loss = 2.30564760
# Iteration 655, loss = 2.30540574
# Iteration 656, loss = 2.30519542
# Iteration 657, loss = 2.30404228
# Iteration 658, loss = 2.30438805
# Iteration 659, loss = 2.30380572
# Iteration 660, loss = 2.30368315
# Iteration 661, loss = 2.30307185
# Iteration 662, loss = 2.30337952
# Iteration 663, loss = 2.30278761
# Iteration 664, loss = 2.30191654
# Iteration 665, loss = 2.30244593
# Iteration 666, loss = 2.30224100
# Iteration 667, loss = 2.30133032
# Iteration 668, loss = 2.30097037
# Iteration 669, loss = 2.30089119
# Iteration 670, loss = 2.30009740
# Iteration 671, loss = 2.29984238
# Iteration 672, loss = 2.29999962
# Iteration 673, loss = 2.29968009
# Iteration 674, loss = 2.29894845
# Iteration 675, loss = 2.29885138
# Iteration 676, loss = 2.29928402
# Iteration 677, loss = 2.29874650
# Iteration 678, loss = 2.29847852
# Iteration 679, loss = 2.29783209
# Iteration 680, loss = 2.29734720
# Iteration 681, loss = 2.29687056
# Iteration 682, loss = 2.29668512
# Iteration 683, loss = 2.29702791
# Iteration 684, loss = 2.29664840
# Iteration 685, loss = 2.29586336
# Iteration 686, loss = 2.29625434
# Iteration 687, loss = 2.29548496
# Iteration 688, loss = 2.29514409
# Iteration 689, loss = 2.29430801
# Iteration 690, loss = 2.29486090
# Iteration 691, loss = 2.29389981
# Iteration 692, loss = 2.29361412
# Iteration 693, loss = 2.29345077
# Iteration 694, loss = 2.29282716
# Iteration 695, loss = 2.29304140
# Iteration 696, loss = 2.29211667
# Iteration 697, loss = 2.29246615
# Iteration 698, loss = 2.29187182
# Iteration 699, loss = 2.29174412
# Iteration 700, loss = 2.29139713
# Iteration 701, loss = 2.29063646
# Iteration 702, loss = 2.29079024
# Iteration 703, loss = 2.29100908
# Iteration 704, loss = 2.28993644
# Iteration 705, loss = 2.28962326
# Iteration 706, loss = 2.29048352
# Iteration 707, loss = 2.28914603
# Iteration 708, loss = 2.28964842
# Iteration 709, loss = 2.28847758
# Iteration 710, loss = 2.28779675
# Iteration 711, loss = 2.28755484
# Iteration 712, loss = 2.28781897
# Iteration 713, loss = 2.28778194
# Iteration 714, loss = 2.28670236
# Iteration 715, loss = 2.28675429
# Iteration 716, loss = 2.28565112
# Iteration 717, loss = 2.28579828
# Iteration 718, loss = 2.28702140
# Iteration 719, loss = 2.28582662
# Iteration 720, loss = 2.28506721
# Iteration 721, loss = 2.28471900
# Iteration 722, loss = 2.28447500
# Iteration 723, loss = 2.28394965
# Iteration 724, loss = 2.28371291
# Iteration 725, loss = 2.28334180
# Iteration 726, loss = 2.28360202
# Iteration 727, loss = 2.28352583
# Iteration 728, loss = 2.28289454
# Iteration 729, loss = 2.28244896
# Iteration 730, loss = 2.28259033
# Iteration 731, loss = 2.28168606
# Iteration 732, loss = 2.28179167
# Iteration 733, loss = 2.28093424
# Iteration 734, loss = 2.28077964
# Iteration 735, loss = 2.28022038
# Iteration 736, loss = 2.27950914
# Iteration 737, loss = 2.27981156
# Iteration 738, loss = 2.27991289
# Iteration 739, loss = 2.27927911
# Iteration 740, loss = 2.27900859
# Iteration 741, loss = 2.27871862
# Iteration 742, loss = 2.27891933
# Iteration 743, loss = 2.27845818
# Iteration 744, loss = 2.27761061
# Iteration 745, loss = 2.27734098
# Iteration 746, loss = 2.27790570
# Iteration 747, loss = 2.27791662
# Iteration 748, loss = 2.27663295
# Iteration 749, loss = 2.27664989
# Iteration 750, loss = 2.27603990
# Iteration 751, loss = 2.27565498
# Iteration 752, loss = 2.27511545
# Iteration 753, loss = 2.27523297
# Iteration 754, loss = 2.27501733
# Iteration 755, loss = 2.27446699
# Iteration 756, loss = 2.27442903
# Iteration 757, loss = 2.27443749
# Iteration 758, loss = 2.27414117
# Iteration 759, loss = 2.27395332
# Iteration 760, loss = 2.27263043
# Iteration 761, loss = 2.27276093
# Iteration 762, loss = 2.27186155
# Iteration 763, loss = 2.27171158
# Iteration 764, loss = 2.27227546
# Iteration 765, loss = 2.27119432
# Iteration 766, loss = 2.27117390
# Iteration 767, loss = 2.27078865
# Iteration 768, loss = 2.27090087
# Iteration 769, loss = 2.27042701
# Iteration 770, loss = 2.26946030
# Iteration 771, loss = 2.27104762
# Iteration 772, loss = 2.26996486
# Iteration 773, loss = 2.26969459
# Iteration 774, loss = 2.26875277
# Iteration 775, loss = 2.26831615
# Iteration 776, loss = 2.26813094
# Iteration 777, loss = 2.26723945
# Iteration 778, loss = 2.26731246
# Iteration 779, loss = 2.26736907
# Iteration 780, loss = 2.26673010
# Iteration 781, loss = 2.26656186
# Iteration 782, loss = 2.26611636
# Iteration 783, loss = 2.26583236
# Iteration 784, loss = 2.26630430
# Iteration 785, loss = 2.26524479
# Iteration 786, loss = 2.26494037
# Iteration 787, loss = 2.26426384
# Iteration 788, loss = 2.26429385
# Iteration 789, loss = 2.26331079
# Iteration 790, loss = 2.26388667
# Iteration 791, loss = 2.26318902
# Iteration 792, loss = 2.26298692
# Iteration 793, loss = 2.26229139
# Iteration 794, loss = 2.26263253
# Iteration 795, loss = 2.26215746
# Iteration 796, loss = 2.26163225
# Iteration 797, loss = 2.26131562
# Iteration 798, loss = 2.26082276
# Iteration 799, loss = 2.26090194
# Iteration 800, loss = 2.26067004
# Iteration 801, loss = 2.26056304
# Iteration 802, loss = 2.26002317
# Iteration 803, loss = 2.25923548
# Iteration 804, loss = 2.25842015
# Iteration 805, loss = 2.25988089
# Iteration 806, loss = 2.25859763
# Iteration 807, loss = 2.25827385
# Iteration 808, loss = 2.25837147
# Iteration 809, loss = 2.25835057
# Iteration 810, loss = 2.25785542
# Iteration 811, loss = 2.25729122
# Iteration 812, loss = 2.25668853
# Iteration 813, loss = 2.25667444
# Iteration 814, loss = 2.25579221
# Iteration 815, loss = 2.25537901
# Iteration 816, loss = 2.25502183
# Iteration 817, loss = 2.25491953
# Iteration 818, loss = 2.25478751
# Iteration 819, loss = 2.25463087
# Iteration 820, loss = 2.25438251
# Iteration 821, loss = 2.25448084
# Iteration 822, loss = 2.25411169
# Iteration 823, loss = 2.25353969
# Iteration 824, loss = 2.25308211
# Iteration 825, loss = 2.25221627
# Iteration 826, loss = 2.25245739
# Iteration 827, loss = 2.25203017
# Iteration 828, loss = 2.25139164
# Iteration 829, loss = 2.25213906
# Iteration 830, loss = 2.25146089
# Iteration 831, loss = 2.25091071
# Iteration 832, loss = 2.25103158
# Iteration 833, loss = 2.25083869
# Iteration 834, loss = 2.25020463
# Iteration 835, loss = 2.25091868
# Iteration 836, loss = 2.24913449
# Iteration 837, loss = 2.24902011
# Iteration 838, loss = 2.24893376
# Iteration 839, loss = 2.24863677
# Iteration 840, loss = 2.24810439
# Iteration 841, loss = 2.24862630
# Iteration 842, loss = 2.24780950
# Iteration 843, loss = 2.24752973
# Iteration 844, loss = 2.24679609
# Iteration 845, loss = 2.24694359
# Iteration 846, loss = 2.24678024
# Iteration 847, loss = 2.24641015
# Iteration 848, loss = 2.24549589
# Iteration 849, loss = 2.24585024
# Iteration 850, loss = 2.24504265
# Iteration 851, loss = 2.24519487
# Iteration 852, loss = 2.24492369
# Iteration 853, loss = 2.24483505
# Iteration 854, loss = 2.24409629
# Iteration 855, loss = 2.24327220
# Iteration 856, loss = 2.24350688
# Iteration 857, loss = 2.24402394
# Iteration 858, loss = 2.24242868
# Iteration 859, loss = 2.24276149
# Iteration 860, loss = 2.24233812
# Iteration 861, loss = 2.24218703
# Iteration 862, loss = 2.24116779
# Iteration 863, loss = 2.24139648
# Iteration 864, loss = 2.24176238
# Iteration 865, loss = 2.24109170
# Iteration 866, loss = 2.24079338
# Iteration 867, loss = 2.24031654
# Iteration 868, loss = 2.24007942
# Iteration 869, loss = 2.24001534
# Iteration 870, loss = 2.24014908
# Iteration 871, loss = 2.23973338
# Iteration 872, loss = 2.23962917
# Iteration 873, loss = 2.23891085
# Iteration 874, loss = 2.23834266
# Iteration 875, loss = 2.23816779
# Iteration 876, loss = 2.23762781
# Iteration 877, loss = 2.23689731
# Iteration 878, loss = 2.23745445
# Iteration 879, loss = 2.23633580
# Iteration 880, loss = 2.23630980
# Iteration 881, loss = 2.23633719
# Iteration 882, loss = 2.23629397
# Iteration 883, loss = 2.23545844
# Iteration 884, loss = 2.23499042
# Iteration 885, loss = 2.23531865
# Iteration 886, loss = 2.23482869
# Iteration 887, loss = 2.23512832
# Iteration 888, loss = 2.23431027
# Iteration 889, loss = 2.23431016
# Iteration 890, loss = 2.23368959
# Iteration 891, loss = 2.23306345
# Iteration 892, loss = 2.23284276
# Iteration 893, loss = 2.23294107
# Iteration 894, loss = 2.23280871
# Iteration 895, loss = 2.23333035
# Iteration 896, loss = 2.23244235
# Iteration 897, loss = 2.23159043
# Iteration 898, loss = 2.23113016
# Iteration 899, loss = 2.23121817
# Iteration 900, loss = 2.23072949
# Iteration 901, loss = 2.23087644
# Iteration 902, loss = 2.22954270
# Iteration 903, loss = 2.23048635
# Iteration 904, loss = 2.22934581
# Iteration 905, loss = 2.22992993
# Iteration 906, loss = 2.22881273
# Iteration 907, loss = 2.22836061
# Iteration 908, loss = 2.22821158
# Iteration 909, loss = 2.22828128
# Iteration 910, loss = 2.22780371
# Iteration 911, loss = 2.22794018
# Iteration 912, loss = 2.22707644
# Iteration 913, loss = 2.22689185
# Iteration 914, loss = 2.22673112
# Iteration 915, loss = 2.22610580
# Iteration 916, loss = 2.22619767
# Iteration 917, loss = 2.22568838
# Iteration 918, loss = 2.22609808
# Iteration 919, loss = 2.22447512
# Iteration 920, loss = 2.22490615
# Iteration 921, loss = 2.22438982
# Iteration 922, loss = 2.22436106
# Iteration 923, loss = 2.22463666
# Iteration 924, loss = 2.22364957
# Iteration 925, loss = 2.22314638
# Iteration 926, loss = 2.22424897
# Iteration 927, loss = 2.22308332
# Iteration 928, loss = 2.22208510
# Iteration 929, loss = 2.22312086
# Iteration 930, loss = 2.22210746
# Iteration 931, loss = 2.22093418
# Iteration 932, loss = 2.22172317
# Iteration 933, loss = 2.22078090
# Iteration 934, loss = 2.22073463
# Iteration 935, loss = 2.22091004
# Iteration 936, loss = 2.22111226
# Iteration 937, loss = 2.22064580
# Iteration 938, loss = 2.22038218
# Iteration 939, loss = 2.21945179
# Iteration 940, loss = 2.21920075
# Iteration 941, loss = 2.21922101
# Iteration 942, loss = 2.21851017
# Iteration 943, loss = 2.21773534
# Iteration 944, loss = 2.21803582
# Iteration 945, loss = 2.21747240
# Iteration 946, loss = 2.21736586
# Iteration 947, loss = 2.21732012
# Iteration 948, loss = 2.21735305
# Iteration 949, loss = 2.21701307
# Iteration 950, loss = 2.21628684
# Iteration 951, loss = 2.21623978
# Iteration 952, loss = 2.21609093
# Iteration 953, loss = 2.21539350
# Iteration 954, loss = 2.21471092
# Iteration 955, loss = 2.21479838
# Iteration 956, loss = 2.21484566
# Iteration 957, loss = 2.21460935
# Iteration 958, loss = 2.21432175
# Iteration 959, loss = 2.21448191
# Iteration 960, loss = 2.21330767
# Iteration 961, loss = 2.21391344
# Iteration 962, loss = 2.21375740
# Iteration 963, loss = 2.21325342
# Iteration 964, loss = 2.21196801
# Iteration 965, loss = 2.21177873
# Iteration 966, loss = 2.21131475
# Iteration 967, loss = 2.21161083
# Iteration 968, loss = 2.21234543
# Iteration 969, loss = 2.21166765
# Iteration 970, loss = 2.21176786
# Iteration 971, loss = 2.21050388
# Iteration 972, loss = 2.21042028
# Iteration 973, loss = 2.20995919
# Iteration 974, loss = 2.20938389
# Iteration 975, loss = 2.20977530
# Iteration 976, loss = 2.20860602
# Iteration 977, loss = 2.20847402
# Iteration 978, loss = 2.20852857
# Iteration 979, loss = 2.20839151
# Iteration 980, loss = 2.20772681
# Iteration 981, loss = 2.20739542
# Iteration 982, loss = 2.20723328
# Iteration 983, loss = 2.20703188
# Iteration 984, loss = 2.20658210
# Iteration 985, loss = 2.20605255
# Iteration 986, loss = 2.20712989
# Iteration 987, loss = 2.20633499
# Iteration 988, loss = 2.20517527
# Iteration 989, loss = 2.20509802
# Iteration 990, loss = 2.20492306
# Iteration 991, loss = 2.20420012
# Iteration 992, loss = 2.20456328
# Iteration 993, loss = 2.20418448
# Iteration 994, loss = 2.20334243
# Iteration 995, loss = 2.20375938
# Iteration 996, loss = 2.20300422
# Iteration 997, loss = 2.20305716
# Iteration 998, loss = 2.20270051
# Iteration 999, loss = 2.20259951
# Iteration 1000, loss = 2.20278523
