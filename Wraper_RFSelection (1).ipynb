# %% [markdown]
# ## *** Feature Selection-Recursive Feature Elimination (RFE)***
#
# The code you provided performs the following steps:
#
# Feature Extraction: Extracts specific features (Smoothness, Entropy, Skewness, StdDev, Mean, Class_Label) from a larger dataset stored in 'concatenated_data.csv'. It saves these extracted features into a new file named 'RFSelection.csv'.
#
# Data Preparation: Loads the extracted features from 'RFSelection.csv', separates features (X) from the target variable (Class_Label, y), and scales the features using StandardScaler for better model performance.
#
# Classifier Initialization: Initializes five different classifiers: Decision Tree, Random Forest, SVM, Neural Network (MLPClassifier), and K-Nearest Neighbors (KNN).
#
# Model Evaluation: Evaluates each classifier using 10-fold stratified cross-validation. It calculates and prints accuracy, precision, recall, specificity, and F1-score for each classifier. It also generates confusion matrices to visualize their performance.
#
# ROC Curve and Accuracy Visualization: Plots ROC curves for Decision Tree and Random Forest classifiers, and visualizes the accuracy of all classifiers using a bar plot. It identifies the best-performing classifier based on cross-validation accuracy.
#
# Loss Curve Plotting for MLPClassifier: Initializes MLPClassifier with specific parameters to enable loss curve recording during training. It then plots the training loss curve to visualize how the model's error decreases over iterations.
#
# Results:
#
# Cross-validation results are displayed for each classifier, showing their performance on unseen data.
#
# Confusion matrices provide a detailed breakdown of predictions for each class, highlighting potential misclassifications.
#
# ROC curves illustrate the trade-off between true positive rate and false positive rate for different
# classification thresholds.
#
# The accuracy bar plot compares the overall accuracy of all classifiers.
# The training loss curve for MLPClassifier shows the decrease in loss over iterations, indicating the model's learning progress.
#
# MLPClassifier loss curve:
#
# The loss curve plots the loss (error) of the MLPClassifier over the training iterations.
#
# Initially, the loss is high, but it gradually decreases as the model learns from the data.
#
# A decreasing loss curve is a good sign, indicating the model is improving its performance.
#
# If the loss curve plateaus or starts to increase, it might suggest issues like overfitting or a need for further training.

# %% [markdown]
# ## Feature extration from feature selection: Selected Feature from Forward Selected Features

# %%
import pandas as pd  # Import pandas for data manipulation
import numpy as np  # Import NumPy for numerical operations
import os  # Import os for directory operations
import re  # Import re for regular expressions

# Define the path to the concatenated feature CSV file
input_directory = '/content/drive/MyDrive/Colab Notebooks/FEDM/CSV Floder/concatenated_data.csv'  # Path to the CSV file

# List of features to extract, including 'Class_Label' as specified
features_to_extract = ['Smoothness', 'Mean', 'Skewness', 'StdDev', 'Mean', 'Class_Label', 'Variance', 'Kurtosis', 'Energy' ]  # Specify the features of interest

# Read the concatenated CSV file into a DataFrame
df = pd.read_csv(input_directory)  # Read the CSV file into a DataFrame

# Verify that each feature exists in the DataFrame columns
existing_features = [feature for feature in features_to_extract if feature in df.columns]
if not existing_features:
    print("None of the specified features are present in the DataFrame.")
else:
    # Extract only the specified features
    extracted_features = df[existing_features]  # Select only the available specified features

    # Rename the DataFrame's index to the filename (if applicable) and keep only the numerical part
    numerical_filename = re.search(r'\d+', os.path.basename(input_directory))  # Extract numerical part from the filename
    if numerical_filename:  # Check if a number was found
        extracted_features['filename'] = numerical_filename.group()  # Add the numerical part as the filename

    # Define the output file path including filename
    output_file_path = '/content/drive/MyDrive/Colab Notebooks/FEDM/final_dataframe.csv'

    # Save the final DataFrame to a new CSV file
    extracted_features.to_csv(output_file_path, index=False)  # Save the extracted features to a CSV file without the index

    print("Extraction completed and saved to:", output_file_path)  # Print completion message
# Out:
# Extraction completed and saved to: /content/drive/MyDrive/Colab Notebooks/FEDM/final_dataframe.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Classifier-DT, KNN , Random Forest, SVM, NN-MPTL

# %% [markdown]
# ## Step 1: Import necessary libraries and load the dataset

# %%
import warnings  # To handle warnings
from sklearn.exceptions import UndefinedMetricWarning, ConvergenceWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)  # Ignore undefined metric warnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)  # Ignore convergence warnings

import os
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve, auc
)
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, label_binarize
from tqdm import tqdm  # For progress bars

# Load dataset as a DataFrame
csv_file = '/content/drive/MyDrive/Colab Notebooks/FEDM/CSV Floder/RFSelection.csv'  # Path to the dataset
data = pd.read_csv(csv_file)  # Read CSV file into a DataFrame

# %% [markdown]
# ## Step 2: Prepare data for modeling

# %%
X = data.drop('Class_Label', axis=1)  # Separate features (X) by dropping the target variable
y = data['Class_Label']  # Target variable (y)

# Feature scaling to standardize features
scaler = StandardScaler()  # Initialize the StandardScaler
X_scaled = scaler.fit_transform(X)  # Fit and transform features

# Initialize classifiers for comparison
classifiers = {
    "DecisionTree": DecisionTreeClassifier(random_state=0),
    "RandomForest": RandomForestClassifier(n_estimators=500, max_depth=None, n_jobs=-1, random_state=0),
    "SVM": SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=0),
    "NeuralNetwork": MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000, random_state=0, learning_rate_init=0.0005, alpha=0.001),
    "KNN_2": KNeighborsClassifier(n_neighbors=2)
}

# Custom class labels for confusion matrix
class_labels = sorted(y.unique())  # Get sorted unique class labels for later use

# %% [markdown]
# ### Step 3: Model evaluation and metrics calculation

# %%
# Function to calculate and display metrics
def print_metrics(y_test, y_pred, clf_name):
    cm = confusion_matrix(y_test, y_pred)  # Compute confusion matrix
    accuracy = accuracy_score(y_test, y_pred)  # Calculate accuracy
    precision = precision_score(y_test, y_pred, average="weighted")  # Calculate precision
    sensitivity = recall_score(y_test, y_pred, average="weighted")  # Calculate recall (sensitivity)
    specificity = np.sum(cm.diagonal()) / np.sum(cm)  # Calculate specificity
    f1 = f1_score(y_test, y_pred, average="weighted")  # Calculate F1-Score

    # Print metrics
    print(f"\nMetrics for {clf_name}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Sensitivity (Recall): {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Confusion matrix visualization
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', cbar=False,
                xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'Confusion Matrix - {clf_name}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    return accuracy, precision, sensitivity, specificity, f1

# Stratified K-Fold for balanced cross-validation
n_folds = 10  # Number of folds for cross-validation
cv = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)  # Initialize K-Fold

# Evaluate classifiers using cross-validation
cv_results = {}  # Dictionary to store cross-validation results
best_classifier = {"name": None, "accuracy": 0}  # To keep track of the best classifier

for clf_name, clf in classifiers.items():  # Loop through each classifier
    print(f"\nEvaluating {clf_name} with {n_folds}-fold cross-validation...")

    # Cross-validation scores for different metrics
    accuracy_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='accuracy')
    precision_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='precision_weighted')
    recall_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='recall_weighted')
    f1_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='f1_weighted')

    # Store results
    cv_results[clf_name] = {
        "accuracy": np.mean(accuracy_scores),
        "precision": np.mean(precision_scores),
        "recall": np.mean(recall_scores),
        "f1_score": np.mean(f1_scores)
    }

    # Print cross-validation results for the classifier
    print(f"Cross-Validation Results for {clf_name}:")
    print(f"  Accuracy: {cv_results[clf_name]['accuracy']:.4f}")
    print(f"  Precision: {cv_results[clf_name]['precision']:.4f}")
    print(f"  Recall (Sensitivity): {cv_results[clf_name]['recall']:.4f}")
    print(f"  F1-Score: {cv_results[clf_name]['f1_score']:.4f}\n")

    # Update the best classifier based on accuracy
    if cv_results[clf_name]["accuracy"] > best_classifier["accuracy"]:
        best_classifier = {"name": clf_name, "accuracy": cv_results[clf_name]["accuracy"]}

    # Fit the classifier on the entire dataset for confusion matrix plot
    clf.fit(X_scaled, y)  # Train the classifier
    y_pred = clf.predict(X_scaled)  # Predict on the scaled data
    print_metrics(y, y_pred, clf_name)  # Print metrics and plot confusion matrix

print(f"Best classifier based on cross-validation: {best_classifier['name']} with accuracy {best_classifier['accuracy']:.4f}")
# Out:
# Evaluating DecisionTree with 10-fold cross-validation...
# Cross-Validation Results for DecisionTree:
#   Accuracy: 0.8617
#   Precision: 0.8797
#   Recall (Sensitivity): 0.8617
#   F1-Score: 0.8617
#
#
# Metrics for DecisionTree:
# Accuracy: 0.9980
# Precision: 0.9980
# Sensitivity (Recall): 0.9980
# Specificity: 0.9980
# F1-Score: 0.9980
# Evaluating RandomForest with 10-fold cross-validation...
# Cross-Validation Results for RandomForest:
#   Accuracy: 0.8699
#   Precision: 0.8846
#   Recall (Sensitivity): 0.8699
#   F1-Score: 0.8692
#
#
# Metrics for RandomForest:
# Accuracy: 0.9980
# Precision: 0.9980
# Sensitivity (Recall): 0.9980
# Specificity: 0.9980
# F1-Score: 0.9980
# Evaluating SVM with 10-fold cross-validation...
# Cross-Validation Results for SVM:
#   Accuracy: 0.1308
#   Precision: 0.3229
#   Recall (Sensitivity): 0.1308
#   F1-Score: 0.1148
#
#
# Metrics for SVM:
# Accuracy: 0.1778
# Precision: 0.6421
# Sensitivity (Recall): 0.1778
# Specificity: 0.1778
# F1-Score: 0.1857
# Evaluating NeuralNetwork with 10-fold cross-validation...
# Cross-Validation Results for NeuralNetwork:
#   Accuracy: 0.2425
#   Precision: 0.2605
#   Recall (Sensitivity): 0.2425
#   F1-Score: 0.2380
#
#
# Metrics for NeuralNetwork:
# Accuracy: 0.4040
# Precision: 0.4154
# Sensitivity (Recall): 0.4040
# Specificity: 0.4040
# F1-Score: 0.3982
# Evaluating KNN_2 with 10-fold cross-validation...
# Cross-Validation Results for KNN_2:
#   Accuracy: 0.5075
#   Precision: 0.5337
#   Recall (Sensitivity): 0.5075
#   F1-Score: 0.4808
#
#
# Metrics for KNN_2:
# Accuracy: 0.9673
# Precision: 0.9682
# Sensitivity (Recall): 0.9673
# Specificity: 0.9673
# F1-Score: 0.9673
# Best classifier based on cross-validation: RandomForest with accuracy 0.8699

# %% [markdown]
# ## Step 4: ROC curve plotting and accuracy visualization

# %%
# Sort classifiers based on mean accuracy in descending order
sorted_classifiers = sorted(cv_results.items(), key=lambda x: x[1]['accuracy'], reverse=True)

# Display the top 3 classifiers
print("\nTop 3 Classifiers based on Mean Accuracy:")
for i, (clf_name, scores) in enumerate(sorted_classifiers[:3], start=1):
    print(f"\nRank {i}: {clf_name}")
    print(f"  Accuracy: {scores['accuracy']:.4f}")
    print(f"  Precision: {scores['precision']:.4f}")
    print(f"  Recall (Sensitivity): {scores['recall']:.4f}")
    print(f"  F1-Score: {scores['f1_score']:.4f}")

# Plotting ROC curves for selected classifiers
selected_classifiers = {
    "DecisionTree": classifiers["DecisionTree"],
    "RandomForest": classifiers["RandomForest"]
}

# Number of folds for cross-validation
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)  # Initialize Stratified K-Fold

for clf_name, clf in selected_classifiers.items():
    plt.figure(figsize=(10, 8))  # Initialize figure for ROC curve
    plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")  # Baseline line for random guessing
    plt.title(f'ROC Curve for {clf_name} with {n_folds}-Fold Cross-Validation')  # Title for the plot
    plt.xlabel('False Positive Rate')  # X-axis label
    plt.ylabel('True Positive Rate')  # Y-axis label

    mean_fpr = np.linspace(0, 1, 100)  # Define mean false positive rate
    tprs, aucs = [], []  # Initialize lists for true positive rates and AUC values

    # Stratified K-Folds cross-validation for ROC curve
    for train_index, test_index in skf.split(X_scaled, y):
        X_train_fold, X_test_fold = X_scaled[train_index], X_scaled[test_index]  # Split data
        y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]  # Split labels

        # Fit the classifier on the training fold
        clf.fit(X_train_fold, y_train_fold)  # Train the classifier on the training data

        # Calculate ROC curve and AUC
        if hasattr(clf, "predict_proba"):  # If the classifier has predict_proba method
            y_proba = clf.predict_proba(X_test_fold)  # Get predicted probabilities
            if len(np.unique(y)) == 2:  # Binary classification
                fpr, tpr, _ = roc_curve(y_test_fold, y_proba[:, 1])  # Calculate ROC for positive class
            else:  # Multi-class classification
                y_test_binarized = label_binarize(y_test_fold, classes=np.unique(y))  # Binarize labels
                fpr, tpr, _ = roc_curve(y_test_binarized.ravel(), y_proba.ravel())  # Calculate ROC for multi-class
        elif hasattr(clf, "decision_function"):  # If the classifier has decision_function method
            y_score = clf.decision_function(X_test_fold)  # Get decision scores
            if len(np.unique(y)) == 2:  # Binary classification
                fpr, tpr, _ = roc_curve(y_test_fold, y_score)  # Calculate ROC for binary
            else:  # Multi-class classification
                y_test_binarized = label_binarize(y_test_fold, classes=np.unique(y))  # Binarize labels
                fpr, tpr, _ = roc_curve(y_test_binarized.ravel(), y_score.ravel())  # Calculate ROC for multi-class
        else:
            print(f"{clf_name} does not support ROC plotting.")  # Warning for unsupported classifiers
            continue

        # Interpolated TPR for consistent mean ROC curve
        interp_tpr = np.interp(mean_fpr, fpr, tpr)  # Interpolate TPR
        interp_tpr[0] = 0.0  # Ensure the first point is 0
        tprs.append(interp_tpr)  # Append interpolated TPR
        aucs.append(auc(fpr, tpr))  # Append AUC

        # Individual ROC curve for each fold
        plt.plot(fpr, tpr, alpha=0.3)  # Plot individual ROC curves

    # Plot mean ROC curve across folds
    mean_tpr = np.mean(tprs, axis=0)  # Calculate mean TPR
    mean_tpr[-1] = 1.0  # Ensure end of TPR is 1.0
    mean_auc = auc(mean_fpr, mean_tpr)  # Calculate mean AUC
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean AUC = {mean_auc:.4f}', lw=2)  # Plot mean ROC curve

    # Finalize plot with legend and axis limits
    plt.legend(loc="lower right")  # Add legend
    plt.xlim([0.0, 1.0])  # Set x-axis limits
    plt.ylim([0.0, 1.05])  # Set y-axis limits
    plt.show()  # Show the plot

# Output the name and accuracy of the best-performing classifier
print("\nBest Classifier Results:")
print(f"Classifier: {best_classifier['name']}")
print(f"Accuracy: {best_classifier['accuracy']:.4f}")
# Out:
# Top 3 Classifiers based on Mean Accuracy:
#
# Rank 1: RandomForest
#   Accuracy: 0.8699
#   Precision: 0.8846
#   Recall (Sensitivity): 0.8699
#   F1-Score: 0.8692
#
# Rank 2: DecisionTree
#   Accuracy: 0.8617
#   Precision: 0.8797
#   Recall (Sensitivity): 0.8617
#   F1-Score: 0.8617
#
# Rank 3: KNN_2
#   Accuracy: 0.5075
#   Precision: 0.5337
#   Recall (Sensitivity): 0.5075
#   F1-Score: 0.4808
# Best Classifier Results:
# Classifier: RandomForest
# Accuracy: 0.8699

# %% [markdown]
# ### Plotting Accuracy Bar Plot for Each Classifier

# %%
# Plotting Accuracy Bar Plot for Each Classifier

# Extract classifier names and their corresponding accuracy scores
classifier_names = list(cv_results.keys())
accuracy_scores = [cv_results[clf]["accuracy"] for clf in classifier_names]

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=accuracy_scores, y=classifier_names, hue=classifier_names, palette="viridis", dodge=False, legend=False)

# Customize plot
plt.title("Accuracy of Each Classifier")
plt.xlabel("Mean Accuracy (Cross-Validated)")
plt.ylabel("Classifier")
plt.xlim(0, 1)  # Set limit to 1 since accuracy ranges from 0 to 1
plt.show()

# %% [markdown]
# ## Initialize MLPClassifier with parameters that ensure the loss curve is recorded

# %%
# Initialize MLPClassifier with parameters that ensure the loss curve is recorded
mlp_clf = MLPClassifier(
    hidden_layer_sizes=(100, 50),
    max_iter=1000,
    random_state=0,
    learning_rate_init=0.0005,
    alpha=0.001,
    verbose=True  # Enables printing progress, including the loss curve tracking
)

# Fit the classifier on the scaled data
mlp_clf.fit(X_scaled, y)

# Plot the loss curve
plt.figure(figsize=(10, 6))
plt.plot(mlp_clf.loss_curve_, label="Training Loss")
plt.title("MLPClassifier Training Loss Curve")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Iteration 1, loss = 2.78635582
# Iteration 2, loss = 2.77039367
# Iteration 3, loss = 2.75915836
# Iteration 4, loss = 2.75032475
# Iteration 5, loss = 2.74277119
# Iteration 6, loss = 2.73613624
# Iteration 7, loss = 2.72962232
# Iteration 8, loss = 2.72408391
# Iteration 9, loss = 2.71881947
# Iteration 10, loss = 2.71357003
# Iteration 11, loss = 2.70925715
# Iteration 12, loss = 2.70507856
# Iteration 13, loss = 2.70145045
# Iteration 14, loss = 2.69703470
# Iteration 15, loss = 2.69365896
# Iteration 16, loss = 2.68986379
# Iteration 17, loss = 2.68690829
# Iteration 18, loss = 2.68352964
# Iteration 19, loss = 2.68024128
# Iteration 20, loss = 2.67704200
# Iteration 21, loss = 2.67454844
# Iteration 22, loss = 2.67142037
# Iteration 23, loss = 2.66822798
# Iteration 24, loss = 2.66586076
# Iteration 25, loss = 2.66308847
# Iteration 26, loss = 2.66030327
# Iteration 27, loss = 2.65774089
# Iteration 28, loss = 2.65527948
# Iteration 29, loss = 2.65273478
# Iteration 30, loss = 2.65039636
# Iteration 31, loss = 2.64832038
# Iteration 32, loss = 2.64593323
# Iteration 33, loss = 2.64337465
# Iteration 34, loss = 2.64125838
# Iteration 35, loss = 2.63919357
# Iteration 36, loss = 2.63697095
# Iteration 37, loss = 2.63492935
# Iteration 38, loss = 2.63281031
# Iteration 39, loss = 2.63083953
# Iteration 40, loss = 2.62876390
# Iteration 41, loss = 2.62704608
# Iteration 42, loss = 2.62516402
# Iteration 43, loss = 2.62323006
# Iteration 44, loss = 2.62105933
# Iteration 45, loss = 2.61917795
# Iteration 46, loss = 2.61731601
# Iteration 47, loss = 2.61582504
# Iteration 48, loss = 2.61391028
# Iteration 49, loss = 2.61212376
# Iteration 50, loss = 2.61020831
# Iteration 51, loss = 2.60875045
# Iteration 52, loss = 2.60694617
# Iteration 53, loss = 2.60533430
# Iteration 54, loss = 2.60348233
# Iteration 55, loss = 2.60233802
# Iteration 56, loss = 2.60080683
# Iteration 57, loss = 2.59879355
# Iteration 58, loss = 2.59706766
# Iteration 59, loss = 2.59599265
# Iteration 60, loss = 2.59430313
# Iteration 61, loss = 2.59218157
# Iteration 62, loss = 2.59091144
# Iteration 63, loss = 2.58965517
# Iteration 64, loss = 2.58803614
# Iteration 65, loss = 2.58654542
# Iteration 66, loss = 2.58508041
# Iteration 67, loss = 2.58357526
# Iteration 68, loss = 2.58198459
# Iteration 69, loss = 2.58093280
# Iteration 70, loss = 2.57882535
# Iteration 71, loss = 2.57805649
# Iteration 72, loss = 2.57627902
# Iteration 73, loss = 2.57458636
# Iteration 74, loss = 2.57351541
# Iteration 75, loss = 2.57153449
# Iteration 76, loss = 2.57042139
# Iteration 77, loss = 2.56869958
# Iteration 78, loss = 2.56736295
# Iteration 79, loss = 2.56591900
# Iteration 80, loss = 2.56458389
# Iteration 81, loss = 2.56328398
# Iteration 82, loss = 2.56188273
# Iteration 83, loss = 2.56039598
# Iteration 84, loss = 2.55881704
# Iteration 85, loss = 2.55769630
# Iteration 86, loss = 2.55599434
# Iteration 87, loss = 2.55450279
# Iteration 88, loss = 2.55339895
# Iteration 89, loss = 2.55215130
# Iteration 90, loss = 2.55064039
# Iteration 91, loss = 2.54942952
# Iteration 92, loss = 2.54797673
# Iteration 93, loss = 2.54707416
# Iteration 94, loss = 2.54542451
# Iteration 95, loss = 2.54473708
# Iteration 96, loss = 2.54325097
# Iteration 97, loss = 2.54187571
# Iteration 98, loss = 2.54083564
# Iteration 99, loss = 2.53912933
# Iteration 100, loss = 2.53850795
# Iteration 101, loss = 2.53696993
# Iteration 102, loss = 2.53505514
# Iteration 103, loss = 2.53424778
# Iteration 104, loss = 2.53349898
# Iteration 105, loss = 2.53194195
# Iteration 106, loss = 2.53093651
# Iteration 107, loss = 2.53015308
# Iteration 108, loss = 2.52863964
# Iteration 109, loss = 2.52743362
# Iteration 110, loss = 2.52599100
# Iteration 111, loss = 2.52512541
# Iteration 112, loss = 2.52378387
# Iteration 113, loss = 2.52252009
# Iteration 114, loss = 2.52142623
# Iteration 115, loss = 2.52014072
# Iteration 116, loss = 2.51911163
# Iteration 117, loss = 2.51772670
# Iteration 118, loss = 2.51685551
# Iteration 119, loss = 2.51572857
# Iteration 120, loss = 2.51458548
# Iteration 121, loss = 2.51369821
# Iteration 122, loss = 2.51300924
# Iteration 123, loss = 2.51123136
# Iteration 124, loss = 2.51048082
# Iteration 125, loss = 2.50892365
# Iteration 126, loss = 2.50831790
# Iteration 127, loss = 2.50707990
# Iteration 128, loss = 2.50577593
# Iteration 129, loss = 2.50467256
# Iteration 130, loss = 2.50376787
# Iteration 131, loss = 2.50297704
# Iteration 132, loss = 2.50133138
# Iteration 133, loss = 2.50042161
# Iteration 134, loss = 2.49932507
# Iteration 135, loss = 2.49813900
# Iteration 136, loss = 2.49735885
# Iteration 137, loss = 2.49631770
# Iteration 138, loss = 2.49508481
# Iteration 139, loss = 2.49420394
# Iteration 140, loss = 2.49335979
# Iteration 141, loss = 2.49261659
# Iteration 142, loss = 2.49132495
# Iteration 143, loss = 2.49010669
# Iteration 144, loss = 2.48890126
# Iteration 145, loss = 2.48827166
# Iteration 146, loss = 2.48773122
# Iteration 147, loss = 2.48612219
# Iteration 148, loss = 2.48552047
# Iteration 149, loss = 2.48450411
# Iteration 150, loss = 2.48303199
# Iteration 151, loss = 2.48194454
# Iteration 152, loss = 2.48125276
# Iteration 153, loss = 2.48033503
# Iteration 154, loss = 2.47892786
# Iteration 155, loss = 2.47835618
# Iteration 156, loss = 2.47696321
# Iteration 157, loss = 2.47604824
# Iteration 158, loss = 2.47487440
# Iteration 159, loss = 2.47417191
# Iteration 160, loss = 2.47277345
# Iteration 161, loss = 2.47213555
# Iteration 162, loss = 2.47111750
# Iteration 163, loss = 2.47049627
# Iteration 164, loss = 2.46936946
# Iteration 165, loss = 2.46844501
# Iteration 166, loss = 2.46783434
# Iteration 167, loss = 2.46631430
# Iteration 168, loss = 2.46544569
# Iteration 169, loss = 2.46428962
# Iteration 170, loss = 2.46348039
# Iteration 171, loss = 2.46261121
# Iteration 172, loss = 2.46145661
# Iteration 173, loss = 2.46049346
# Iteration 174, loss = 2.45949405
# Iteration 175, loss = 2.45872341
# Iteration 176, loss = 2.45762846
# Iteration 177, loss = 2.45716731
# Iteration 178, loss = 2.45584511
# Iteration 179, loss = 2.45512738
# Iteration 180, loss = 2.45443730
# Iteration 181, loss = 2.45383216
# Iteration 182, loss = 2.45262299
# Iteration 183, loss = 2.45123675
# Iteration 184, loss = 2.45122126
# Iteration 185, loss = 2.44977787
# Iteration 186, loss = 2.44897469
# Iteration 187, loss = 2.44829615
# Iteration 188, loss = 2.44697815
# Iteration 189, loss = 2.44631348
# Iteration 190, loss = 2.44542002
# Iteration 191, loss = 2.44406702
# Iteration 192, loss = 2.44378939
# Iteration 193, loss = 2.44302348
# Iteration 194, loss = 2.44156480
# Iteration 195, loss = 2.44047225
# Iteration 196, loss = 2.43960395
# Iteration 197, loss = 2.43887334
# Iteration 198, loss = 2.43804538
# Iteration 199, loss = 2.43714431
# Iteration 200, loss = 2.43655727
# Iteration 201, loss = 2.43517968
# Iteration 202, loss = 2.43511631
# Iteration 203, loss = 2.43364139
# Iteration 204, loss = 2.43279979
# Iteration 205, loss = 2.43188916
# Iteration 206, loss = 2.43255137
# Iteration 207, loss = 2.43023342
# Iteration 208, loss = 2.42973954
# Iteration 209, loss = 2.42906308
# Iteration 210, loss = 2.42798293
# Iteration 211, loss = 2.42705883
# Iteration 212, loss = 2.42548729
# Iteration 213, loss = 2.42520701
# Iteration 214, loss = 2.42420853
# Iteration 215, loss = 2.42430239
# Iteration 216, loss = 2.42373085
# Iteration 217, loss = 2.42186600
# Iteration 218, loss = 2.42086806
# Iteration 219, loss = 2.42018814
# Iteration 220, loss = 2.41968191
# Iteration 221, loss = 2.41859003
# Iteration 222, loss = 2.41782375
# Iteration 223, loss = 2.41675714
# Iteration 224, loss = 2.41609486
# Iteration 225, loss = 2.41503387
# Iteration 226, loss = 2.41434338
# Iteration 227, loss = 2.41334909
# Iteration 228, loss = 2.41251944
# Iteration 229, loss = 2.41147326
# Iteration 230, loss = 2.41089313
# Iteration 231, loss = 2.41014940
# Iteration 232, loss = 2.40908171
# Iteration 233, loss = 2.40876151
# Iteration 234, loss = 2.40769799
# Iteration 235, loss = 2.40679429
# Iteration 236, loss = 2.40591120
# Iteration 237, loss = 2.40476978
# Iteration 238, loss = 2.40389155
# Iteration 239, loss = 2.40319230
# Iteration 240, loss = 2.40251871
# Iteration 241, loss = 2.40133407
# Iteration 242, loss = 2.40099958
# Iteration 243, loss = 2.40024625
# Iteration 244, loss = 2.39969401
# Iteration 245, loss = 2.39827230
# Iteration 246, loss = 2.39774075
# Iteration 247, loss = 2.39732799
# Iteration 248, loss = 2.39620232
# Iteration 249, loss = 2.39558273
# Iteration 250, loss = 2.39474974
# Iteration 251, loss = 2.39366946
# Iteration 252, loss = 2.39239139
# Iteration 253, loss = 2.39237621
# Iteration 254, loss = 2.39108196
# Iteration 255, loss = 2.39049068
# Iteration 256, loss = 2.38966098
# Iteration 257, loss = 2.38861384
# Iteration 258, loss = 2.38796474
# Iteration 259, loss = 2.38722246
# Iteration 260, loss = 2.38612113
# Iteration 261, loss = 2.38556153
# Iteration 262, loss = 2.38481648
# Iteration 263, loss = 2.38419571
# Iteration 264, loss = 2.38337289
# Iteration 265, loss = 2.38258861
# Iteration 266, loss = 2.38149497
# Iteration 267, loss = 2.38108306
# Iteration 268, loss = 2.38029859
# Iteration 269, loss = 2.37950850
# Iteration 270, loss = 2.37885373
# Iteration 271, loss = 2.37793056
# Iteration 272, loss = 2.37736254
# Iteration 273, loss = 2.37661444
# Iteration 274, loss = 2.37601701
# Iteration 275, loss = 2.37502639
# Iteration 276, loss = 2.37369948
# Iteration 277, loss = 2.37295362
# Iteration 278, loss = 2.37257378
# Iteration 279, loss = 2.37164282
# Iteration 280, loss = 2.37032390
# Iteration 281, loss = 2.36976036
# Iteration 282, loss = 2.36884204
# Iteration 283, loss = 2.36817421
# Iteration 284, loss = 2.36790320
# Iteration 285, loss = 2.36676152
# Iteration 286, loss = 2.36582753
# Iteration 287, loss = 2.36556917
# Iteration 288, loss = 2.36413516
# Iteration 289, loss = 2.36359252
# Iteration 290, loss = 2.36311078
# Iteration 291, loss = 2.36248106
# Iteration 292, loss = 2.36169496
# Iteration 293, loss = 2.36146946
# Iteration 294, loss = 2.36096887
# Iteration 295, loss = 2.35963672
# Iteration 296, loss = 2.35877421
# Iteration 297, loss = 2.35784958
# Iteration 298, loss = 2.35783227
# Iteration 299, loss = 2.35642269
# Iteration 300, loss = 2.35533337
# Iteration 301, loss = 2.35469162
# Iteration 302, loss = 2.35391842
# Iteration 303, loss = 2.35332270
# Iteration 304, loss = 2.35269113
# Iteration 305, loss = 2.35169076
# Iteration 306, loss = 2.35150271
# Iteration 307, loss = 2.35021953
# Iteration 308, loss = 2.34984418
# Iteration 309, loss = 2.34903566
# Iteration 310, loss = 2.34855664
# Iteration 311, loss = 2.34796337
# Iteration 312, loss = 2.34673491
# Iteration 313, loss = 2.34662810
# Iteration 314, loss = 2.34598278
# Iteration 315, loss = 2.34491440
# Iteration 316, loss = 2.34426383
# Iteration 317, loss = 2.34362740
# Iteration 318, loss = 2.34204516
# Iteration 319, loss = 2.34192777
# Iteration 320, loss = 2.34101413
# Iteration 321, loss = 2.34045938
# Iteration 322, loss = 2.33995864
# Iteration 323, loss = 2.33876771
# Iteration 324, loss = 2.33921265
# Iteration 325, loss = 2.33763163
# Iteration 326, loss = 2.33645457
# Iteration 327, loss = 2.33611974
# Iteration 328, loss = 2.33563931
# Iteration 329, loss = 2.33485560
# Iteration 330, loss = 2.33430832
# Iteration 331, loss = 2.33355006
# Iteration 332, loss = 2.33305983
# Iteration 333, loss = 2.33256393
# Iteration 334, loss = 2.33190577
# Iteration 335, loss = 2.33063808
# Iteration 336, loss = 2.32973362
# Iteration 337, loss = 2.32898558
# Iteration 338, loss = 2.32876779
# Iteration 339, loss = 2.32763292
# Iteration 340, loss = 2.32699528
# Iteration 341, loss = 2.32684449
# Iteration 342, loss = 2.32505460
# Iteration 343, loss = 2.32479323
# Iteration 344, loss = 2.32552358
# Iteration 345, loss = 2.32403815
# Iteration 346, loss = 2.32349960
# Iteration 347, loss = 2.32229407
# Iteration 348, loss = 2.32149227
# Iteration 349, loss = 2.32121539
# Iteration 350, loss = 2.32010202
# Iteration 351, loss = 2.31980745
# Iteration 352, loss = 2.31923873
# Iteration 353, loss = 2.31828345
# Iteration 354, loss = 2.31753272
# Iteration 355, loss = 2.31665400
# Iteration 356, loss = 2.31567426
# Iteration 357, loss = 2.31561808
# Iteration 358, loss = 2.31503437
# Iteration 359, loss = 2.31458707
# Iteration 360, loss = 2.31332204
# Iteration 361, loss = 2.31213293
# Iteration 362, loss = 2.31246639
# Iteration 363, loss = 2.31127646
# Iteration 364, loss = 2.31085134
# Iteration 365, loss = 2.30977089
# Iteration 366, loss = 2.30963548
# Iteration 367, loss = 2.30922469
# Iteration 368, loss = 2.30806307
# Iteration 369, loss = 2.30804925
# Iteration 370, loss = 2.30736708
# Iteration 371, loss = 2.30748567
# Iteration 372, loss = 2.30555673
# Iteration 373, loss = 2.30524914
# Iteration 374, loss = 2.30408969
# Iteration 375, loss = 2.30314251
# Iteration 376, loss = 2.30321337
# Iteration 377, loss = 2.30271016
# Iteration 378, loss = 2.30166729
# Iteration 379, loss = 2.30054706
# Iteration 380, loss = 2.30083187
# Iteration 381, loss = 2.29954061
# Iteration 382, loss = 2.29891943
# Iteration 383, loss = 2.29811548
# Iteration 384, loss = 2.29778710
# Iteration 385, loss = 2.29676746
# Iteration 386, loss = 2.29636870
# Iteration 387, loss = 2.29652260
# Iteration 388, loss = 2.29621088
# Iteration 389, loss = 2.29465419
# Iteration 390, loss = 2.29347489
# Iteration 391, loss = 2.29387201
# Iteration 392, loss = 2.29280516
# Iteration 393, loss = 2.29155040
# Iteration 394, loss = 2.29082024
# Iteration 395, loss = 2.29072682
# Iteration 396, loss = 2.28941729
# Iteration 397, loss = 2.29024553
# Iteration 398, loss = 2.28855843
# Iteration 399, loss = 2.28794589
# Iteration 400, loss = 2.28797127
# Iteration 401, loss = 2.28747681
# Iteration 402, loss = 2.28615611
# Iteration 403, loss = 2.28534882
# Iteration 404, loss = 2.28454220
# Iteration 405, loss = 2.28406883
# Iteration 406, loss = 2.28414926
# Iteration 407, loss = 2.28241808
# Iteration 408, loss = 2.28219077
# Iteration 409, loss = 2.28147958
# Iteration 410, loss = 2.28090676
# Iteration 411, loss = 2.28019540
# Iteration 412, loss = 2.27962871
# Iteration 413, loss = 2.27895254
# Iteration 414, loss = 2.27954083
# Iteration 415, loss = 2.27770687
# Iteration 416, loss = 2.27694939
# Iteration 417, loss = 2.27637851
# Iteration 418, loss = 2.27587994
# Iteration 419, loss = 2.27519979
# Iteration 420, loss = 2.27469358
# Iteration 421, loss = 2.27388536
# Iteration 422, loss = 2.27374061
# Iteration 423, loss = 2.27224061
# Iteration 424, loss = 2.27175964
# Iteration 425, loss = 2.27169767
# Iteration 426, loss = 2.27026290
# Iteration 427, loss = 2.26999286
# Iteration 428, loss = 2.26958483
# Iteration 429, loss = 2.26886408
# Iteration 430, loss = 2.26912351
# Iteration 431, loss = 2.26755145
# Iteration 432, loss = 2.26714133
# Iteration 433, loss = 2.26610629
# Iteration 434, loss = 2.26531503
# Iteration 435, loss = 2.26501765
# Iteration 436, loss = 2.26520428
# Iteration 437, loss = 2.26369426
# Iteration 438, loss = 2.26322889
# Iteration 439, loss = 2.26266508
# Iteration 440, loss = 2.26184047
# Iteration 441, loss = 2.26116841
# Iteration 442, loss = 2.26068312
# Iteration 443, loss = 2.25997557
# Iteration 444, loss = 2.25947486
# Iteration 445, loss = 2.25944773
# Iteration 446, loss = 2.25883440
# Iteration 447, loss = 2.25776185
# Iteration 448, loss = 2.25687024
# Iteration 449, loss = 2.25626562
# Iteration 450, loss = 2.25578889
# Iteration 451, loss = 2.25500936
# Iteration 452, loss = 2.25434592
# Iteration 453, loss = 2.25323553
# Iteration 454, loss = 2.25284020
# Iteration 455, loss = 2.25221127
# Iteration 456, loss = 2.25240390
# Iteration 457, loss = 2.25149224
# Iteration 458, loss = 2.25057831
# Iteration 459, loss = 2.24970857
# Iteration 460, loss = 2.25019291
# Iteration 461, loss = 2.24831772
# Iteration 462, loss = 2.24887764
# Iteration 463, loss = 2.24860373
# Iteration 464, loss = 2.24662455
# Iteration 465, loss = 2.24623199
# Iteration 466, loss = 2.24534142
# Iteration 467, loss = 2.24570638
# Iteration 468, loss = 2.24485227
# Iteration 469, loss = 2.24418675
# Iteration 470, loss = 2.24337345
# Iteration 471, loss = 2.24279366
# Iteration 472, loss = 2.24212773
# Iteration 473, loss = 2.24134805
# Iteration 474, loss = 2.24052964
# Iteration 475, loss = 2.24019982
# Iteration 476, loss = 2.23932787
# Iteration 477, loss = 2.23908731
# Iteration 478, loss = 2.23807282
# Iteration 479, loss = 2.23789542
# Iteration 480, loss = 2.23825516
# Iteration 481, loss = 2.23666081
# Iteration 482, loss = 2.23677187
# Iteration 483, loss = 2.23634756
# Iteration 484, loss = 2.23621233
# Iteration 485, loss = 2.23404156
# Iteration 486, loss = 2.23387683
# Iteration 487, loss = 2.23260167
# Iteration 488, loss = 2.23199226
# Iteration 489, loss = 2.23279380
# Iteration 490, loss = 2.23087914
# Iteration 491, loss = 2.23073624
# Iteration 492, loss = 2.23005606
# Iteration 493, loss = 2.22928852
# Iteration 494, loss = 2.22922406
# Iteration 495, loss = 2.22763123
# Iteration 496, loss = 2.22756333
# Iteration 497, loss = 2.22664969
# Iteration 498, loss = 2.22594241
# Iteration 499, loss = 2.22489241
# Iteration 500, loss = 2.22498432
# Iteration 501, loss = 2.22512324
# Iteration 502, loss = 2.22390921
# Iteration 503, loss = 2.22364753
# Iteration 504, loss = 2.22272347
# Iteration 505, loss = 2.22179763
# Iteration 506, loss = 2.22234732
# Iteration 507, loss = 2.22227625
# Iteration 508, loss = 2.22024672
# Iteration 509, loss = 2.21946981
# Iteration 510, loss = 2.21862259
# Iteration 511, loss = 2.21837923
# Iteration 512, loss = 2.21809425
# Iteration 513, loss = 2.21718909
# Iteration 514, loss = 2.21640769
# Iteration 515, loss = 2.21634743
# Iteration 516, loss = 2.21498732
# Iteration 517, loss = 2.21440308
# Iteration 518, loss = 2.21411816
# Iteration 519, loss = 2.21336866
# Iteration 520, loss = 2.21276972
# Iteration 521, loss = 2.21197348
# Iteration 522, loss = 2.21132639
# Iteration 523, loss = 2.21133249
# Iteration 524, loss = 2.21036209
# Iteration 525, loss = 2.20976224
# Iteration 526, loss = 2.20953942
# Iteration 527, loss = 2.20908364
# Iteration 528, loss = 2.20739951
# Iteration 529, loss = 2.20712813
# Iteration 530, loss = 2.20691452
# Iteration 531, loss = 2.20607599
# Iteration 532, loss = 2.20574637
# Iteration 533, loss = 2.20495255
# Iteration 534, loss = 2.20452983
# Iteration 535, loss = 2.20338750
# Iteration 536, loss = 2.20319919
# Iteration 537, loss = 2.20211681
# Iteration 538, loss = 2.20174772
# Iteration 539, loss = 2.20084099
# Iteration 540, loss = 2.20008931
# Iteration 541, loss = 2.20019040
# Iteration 542, loss = 2.19953638
# Iteration 543, loss = 2.19854967
# Iteration 544, loss = 2.19807374
# Iteration 545, loss = 2.19730844
# Iteration 546, loss = 2.19691615
# Iteration 547, loss = 2.19624778
# Iteration 548, loss = 2.19549843
# Iteration 549, loss = 2.19510143
# Iteration 550, loss = 2.19395034
# Iteration 551, loss = 2.19427486
# Iteration 552, loss = 2.19397793
# Iteration 553, loss = 2.19261586
# Iteration 554, loss = 2.19218711
# Iteration 555, loss = 2.19137446
# Iteration 556, loss = 2.19116709
# Iteration 557, loss = 2.19010042
# Iteration 558, loss = 2.19042687
# Iteration 559, loss = 2.18916411
# Iteration 560, loss = 2.18831838
# Iteration 561, loss = 2.18822927
# Iteration 562, loss = 2.18661051
# Iteration 563, loss = 2.18611254
# Iteration 564, loss = 2.18568707
# Iteration 565, loss = 2.18522651
# Iteration 566, loss = 2.18453577
# Iteration 567, loss = 2.18421170
# Iteration 568, loss = 2.18339323
# Iteration 569, loss = 2.18246246
# Iteration 570, loss = 2.18188127
# Iteration 571, loss = 2.18164345
# Iteration 572, loss = 2.18052851
# Iteration 573, loss = 2.18067041
# Iteration 574, loss = 2.17931827
# Iteration 575, loss = 2.17917484
# Iteration 576, loss = 2.17813346
# Iteration 577, loss = 2.17729744
# Iteration 578, loss = 2.17692744
# Iteration 579, loss = 2.17645005
# Iteration 580, loss = 2.17627709
# Iteration 581, loss = 2.17493465
# Iteration 582, loss = 2.17645889
# Iteration 583, loss = 2.17387004
# Iteration 584, loss = 2.17366271
# Iteration 585, loss = 2.17349274
# Iteration 586, loss = 2.17275363
# Iteration 587, loss = 2.17146519
# Iteration 588, loss = 2.17080253
# Iteration 589, loss = 2.17067202
# Iteration 590, loss = 2.16985623
# Iteration 591, loss = 2.16925249
# Iteration 592, loss = 2.16849512
# Iteration 593, loss = 2.16818100
# Iteration 594, loss = 2.16811782
# Iteration 595, loss = 2.16711647
# Iteration 596, loss = 2.16595311
# Iteration 597, loss = 2.16589914
# Iteration 598, loss = 2.16481915
# Iteration 599, loss = 2.16421214
# Iteration 600, loss = 2.16399422
# Iteration 601, loss = 2.16287683
# Iteration 602, loss = 2.16272926
# Iteration 603, loss = 2.16284897
# Iteration 604, loss = 2.16172247
# Iteration 605, loss = 2.16102242
# Iteration 606, loss = 2.16030336
# Iteration 607, loss = 2.15926076
# Iteration 608, loss = 2.15906934
# Iteration 609, loss = 2.15867964
# Iteration 610, loss = 2.15802676
# Iteration 611, loss = 2.15751688
# Iteration 612, loss = 2.15665312
# Iteration 613, loss = 2.15576694
# Iteration 614, loss = 2.15556936
# Iteration 615, loss = 2.15477226
# Iteration 616, loss = 2.15436722
# Iteration 617, loss = 2.15358220
# Iteration 618, loss = 2.15349614
# Iteration 619, loss = 2.15251064
# Iteration 620, loss = 2.15197066
# Iteration 621, loss = 2.15122962
# Iteration 622, loss = 2.15037353
# Iteration 623, loss = 2.14911086
# Iteration 624, loss = 2.14901571
# Iteration 625, loss = 2.14870872
# Iteration 626, loss = 2.14787362
# Iteration 627, loss = 2.14739509
# Iteration 628, loss = 2.14678827
# Iteration 629, loss = 2.14638233
# Iteration 630, loss = 2.14461134
# Iteration 631, loss = 2.14420347
# Iteration 632, loss = 2.14393335
# Iteration 633, loss = 2.14327971
# Iteration 634, loss = 2.14276777
# Iteration 635, loss = 2.14199510
# Iteration 636, loss = 2.14220608
# Iteration 637, loss = 2.14103446
# Iteration 638, loss = 2.14035636
# Iteration 639, loss = 2.14039877
# Iteration 640, loss = 2.13941517
# Iteration 641, loss = 2.13782009
# Iteration 642, loss = 2.13935781
# Iteration 643, loss = 2.13845464
# Iteration 644, loss = 2.13639337
# Iteration 645, loss = 2.13658084
# Iteration 646, loss = 2.13543570
# Iteration 647, loss = 2.13484569
# Iteration 648, loss = 2.13478637
# Iteration 649, loss = 2.13476551
# Iteration 650, loss = 2.13299063
# Iteration 651, loss = 2.13212904
# Iteration 652, loss = 2.13197162
# Iteration 653, loss = 2.13101306
# Iteration 654, loss = 2.13088475
# Iteration 655, loss = 2.13063940
# Iteration 656, loss = 2.12931124
# Iteration 657, loss = 2.12910447
# Iteration 658, loss = 2.12847128
# Iteration 659, loss = 2.12830240
# Iteration 660, loss = 2.12748943
# Iteration 661, loss = 2.12713162
# Iteration 662, loss = 2.12545502
# Iteration 663, loss = 2.12569581
# Iteration 664, loss = 2.12508649
# Iteration 665, loss = 2.12413499
# Iteration 666, loss = 2.12315074
# Iteration 667, loss = 2.12313751
# Iteration 668, loss = 2.12191032
# Iteration 669, loss = 2.12184393
# Iteration 670, loss = 2.12090159
# Iteration 671, loss = 2.12018626
# Iteration 672, loss = 2.12010933
# Iteration 673, loss = 2.11902472
# Iteration 674, loss = 2.11873840
# Iteration 675, loss = 2.11811606
# Iteration 676, loss = 2.11781849
# Iteration 677, loss = 2.11702925
# Iteration 678, loss = 2.11645332
# Iteration 679, loss = 2.11492180
# Iteration 680, loss = 2.11504143
# Iteration 681, loss = 2.11450464
# Iteration 682, loss = 2.11462323
# Iteration 683, loss = 2.11280372
# Iteration 684, loss = 2.11261868
# Iteration 685, loss = 2.11188452
# Iteration 686, loss = 2.11192427
# Iteration 687, loss = 2.11126145
# Iteration 688, loss = 2.11007059
# Iteration 689, loss = 2.10942445
# Iteration 690, loss = 2.10940356
# Iteration 691, loss = 2.10916060
# Iteration 692, loss = 2.10782884
# Iteration 693, loss = 2.10688833
# Iteration 694, loss = 2.10728196
# Iteration 695, loss = 2.10590658
# Iteration 696, loss = 2.10536145
# Iteration 697, loss = 2.10453835
# Iteration 698, loss = 2.10421485
# Iteration 699, loss = 2.10347688
# Iteration 700, loss = 2.10290721
# Iteration 701, loss = 2.10224756
# Iteration 702, loss = 2.10158788
# Iteration 703, loss = 2.10167606
# Iteration 704, loss = 2.10032933
# Iteration 705, loss = 2.10123731
# Iteration 706, loss = 2.10025393
# Iteration 707, loss = 2.09862380
# Iteration 708, loss = 2.09842124
# Iteration 709, loss = 2.09733089
# Iteration 710, loss = 2.09663098
# Iteration 711, loss = 2.09638310
# Iteration 712, loss = 2.09612964
# Iteration 713, loss = 2.09538442
# Iteration 714, loss = 2.09395281
# Iteration 715, loss = 2.09465165
# Iteration 716, loss = 2.09401335
# Iteration 717, loss = 2.09300045
# Iteration 718, loss = 2.09257419
# Iteration 719, loss = 2.09220764
# Iteration 720, loss = 2.09092090
# Iteration 721, loss = 2.09078075
# Iteration 722, loss = 2.08974157
# Iteration 723, loss = 2.08973739
# Iteration 724, loss = 2.08870130
# Iteration 725, loss = 2.08796911
# Iteration 726, loss = 2.08700054
# Iteration 727, loss = 2.08705309
# Iteration 728, loss = 2.08629398
# Iteration 729, loss = 2.08566815
# Iteration 730, loss = 2.08481211
# Iteration 731, loss = 2.08471487
# Iteration 732, loss = 2.08365295
# Iteration 733, loss = 2.08301011
# Iteration 734, loss = 2.08256000
# Iteration 735, loss = 2.08183942
# Iteration 736, loss = 2.08113193
# Iteration 737, loss = 2.08129567
# Iteration 738, loss = 2.08052853
# Iteration 739, loss = 2.08012382
# Iteration 740, loss = 2.07928411
# Iteration 741, loss = 2.07873903
# Iteration 742, loss = 2.07804129
# Iteration 743, loss = 2.07719215
# Iteration 744, loss = 2.07654486
# Iteration 745, loss = 2.07582081
# Iteration 746, loss = 2.07664785
# Iteration 747, loss = 2.07548101
# Iteration 748, loss = 2.07469226
# Iteration 749, loss = 2.07415336
# Iteration 750, loss = 2.07235854
# Iteration 751, loss = 2.07350557
# Iteration 752, loss = 2.07171342
# Iteration 753, loss = 2.07231060
# Iteration 754, loss = 2.07099393
# Iteration 755, loss = 2.07013893
# Iteration 756, loss = 2.06945800
# Iteration 757, loss = 2.06861520
# Iteration 758, loss = 2.06790000
# Iteration 759, loss = 2.06792436
# Iteration 760, loss = 2.06763899
# Iteration 761, loss = 2.06629669
# Iteration 762, loss = 2.06625147
# Iteration 763, loss = 2.06529300
# Iteration 764, loss = 2.06466469
# Iteration 765, loss = 2.06403528
# Iteration 766, loss = 2.06318447
# Iteration 767, loss = 2.06246750
# Iteration 768, loss = 2.06214595
# Iteration 769, loss = 2.06084034
# Iteration 770, loss = 2.06075725
# Iteration 771, loss = 2.05979074
# Iteration 772, loss = 2.05950262
# Iteration 773, loss = 2.05874285
# Iteration 774, loss = 2.05877297
# Iteration 775, loss = 2.05806534
# Iteration 776, loss = 2.05800643
# Iteration 777, loss = 2.05713955
# Iteration 778, loss = 2.05686804
# Iteration 779, loss = 2.05687037
# Iteration 780, loss = 2.05494759
# Iteration 781, loss = 2.05449624
# Iteration 782, loss = 2.05336993
# Iteration 783, loss = 2.05284759
# Iteration 784, loss = 2.05195504
# Iteration 785, loss = 2.05219615
# Iteration 786, loss = 2.05106545
# Iteration 787, loss = 2.05058302
# Iteration 788, loss = 2.05005518
# Iteration 789, loss = 2.04990973
# Iteration 790, loss = 2.04878689
# Iteration 791, loss = 2.04867180
# Iteration 792, loss = 2.04852510
# Iteration 793, loss = 2.04706958
# Iteration 794, loss = 2.04705520
# Iteration 795, loss = 2.04602370
# Iteration 796, loss = 2.04543599
# Iteration 797, loss = 2.04451802
# Iteration 798, loss = 2.04433279
# Iteration 799, loss = 2.04438011
# Iteration 800, loss = 2.04320053
# Iteration 801, loss = 2.04178592
# Iteration 802, loss = 2.04235855
# Iteration 803, loss = 2.04034790
# Iteration 804, loss = 2.04008463
# Iteration 805, loss = 2.03989323
# Iteration 806, loss = 2.03980839
# Iteration 807, loss = 2.03831604
# Iteration 808, loss = 2.03792535
# Iteration 809, loss = 2.03795827
# Iteration 810, loss = 2.03790671
# Iteration 811, loss = 2.03680166
# Iteration 812, loss = 2.03628721
# Iteration 813, loss = 2.03481394
# Iteration 814, loss = 2.03484750
# Iteration 815, loss = 2.03444417
# Iteration 816, loss = 2.03311174
# Iteration 817, loss = 2.03259533
# Iteration 818, loss = 2.03202404
# Iteration 819, loss = 2.03138307
# Iteration 820, loss = 2.03105545
# Iteration 821, loss = 2.03042583
# Iteration 822, loss = 2.02974337
# Iteration 823, loss = 2.02869435
# Iteration 824, loss = 2.02866444
# Iteration 825, loss = 2.02768097
# Iteration 826, loss = 2.02701507
# Iteration 827, loss = 2.02651423
# Iteration 828, loss = 2.02734529
# Iteration 829, loss = 2.02642463
# Iteration 830, loss = 2.02432338
# Iteration 831, loss = 2.02480369
# Iteration 832, loss = 2.02425320
# Iteration 833, loss = 2.02401295
# Iteration 834, loss = 2.02335086
# Iteration 835, loss = 2.02235919
# Iteration 836, loss = 2.02084242
# Iteration 837, loss = 2.02036396
# Iteration 838, loss = 2.02027213
# Iteration 839, loss = 2.01919796
# Iteration 840, loss = 2.01854713
# Iteration 841, loss = 2.01808870
# Iteration 842, loss = 2.01761051
# Iteration 843, loss = 2.01717172
# Iteration 844, loss = 2.01768643
# Iteration 845, loss = 2.01594813
# Iteration 846, loss = 2.01562146
# Iteration 847, loss = 2.01516809
# Iteration 848, loss = 2.01508653
# Iteration 849, loss = 2.01544512
# Iteration 850, loss = 2.01333638
# Iteration 851, loss = 2.01217249
# Iteration 852, loss = 2.01214989
# Iteration 853, loss = 2.01144445
# Iteration 854, loss = 2.01111986
# Iteration 855, loss = 2.00961816
# Iteration 856, loss = 2.00970426
# Iteration 857, loss = 2.00892523
# Iteration 858, loss = 2.00816110
# Iteration 859, loss = 2.00780382
# Iteration 860, loss = 2.00740547
# Iteration 861, loss = 2.00618773
# Iteration 862, loss = 2.00574206
# Iteration 863, loss = 2.00598485
# Iteration 864, loss = 2.00556845
# Iteration 865, loss = 2.00505125
# Iteration 866, loss = 2.00444151
# Iteration 867, loss = 2.00283841
# Iteration 868, loss = 2.00230295
# Iteration 869, loss = 2.00239546
# Iteration 870, loss = 2.00084962
# Iteration 871, loss = 2.00258947
# Iteration 872, loss = 2.00015109
# Iteration 873, loss = 2.00024917
# Iteration 874, loss = 1.99866744
# Iteration 875, loss = 1.99860580
# Iteration 876, loss = 1.99756100
# Iteration 877, loss = 1.99733941
# Iteration 878, loss = 1.99605286
# Iteration 879, loss = 1.99638591
# Iteration 880, loss = 1.99517720
# Iteration 881, loss = 1.99533643
# Iteration 882, loss = 1.99383973
# Iteration 883, loss = 1.99366628
# Iteration 884, loss = 1.99325542
# Iteration 885, loss = 1.99220749
# Iteration 886, loss = 1.99158526
# Iteration 887, loss = 1.99077721
# Iteration 888, loss = 1.99055534
# Iteration 889, loss = 1.99010017
# Iteration 890, loss = 1.98962983
# Iteration 891, loss = 1.98867585
# Iteration 892, loss = 1.98802663
# Iteration 893, loss = 1.98734416
# Iteration 894, loss = 1.98657659
# Iteration 895, loss = 1.98577085
# Iteration 896, loss = 1.98516525
# Iteration 897, loss = 1.98512040
# Iteration 898, loss = 1.98474380
# Iteration 899, loss = 1.98377482
# Iteration 900, loss = 1.98350466
# Iteration 901, loss = 1.98246628
# Iteration 902, loss = 1.98212631
# Iteration 903, loss = 1.98181402
# Iteration 904, loss = 1.98131393
# Iteration 905, loss = 1.98060464
# Iteration 906, loss = 1.97966156
# Iteration 907, loss = 1.97903297
# Iteration 908, loss = 1.97867911
# Iteration 909, loss = 1.97784047
# Iteration 910, loss = 1.97709201
# Iteration 911, loss = 1.97614864
# Iteration 912, loss = 1.97665987
# Iteration 913, loss = 1.97557058
# Iteration 914, loss = 1.97462416
# Iteration 915, loss = 1.97402203
# Iteration 916, loss = 1.97334892
# Iteration 917, loss = 1.97432940
# Iteration 918, loss = 1.97352140
# Iteration 919, loss = 1.97131959
# Iteration 920, loss = 1.97176146
# Iteration 921, loss = 1.97071443
# Iteration 922, loss = 1.97002849
# Iteration 923, loss = 1.96878564
# Iteration 924, loss = 1.96871212
# Iteration 925, loss = 1.96832342
# Iteration 926, loss = 1.96786625
# Iteration 927, loss = 1.96676621
# Iteration 928, loss = 1.96649740
# Iteration 929, loss = 1.96586909
# Iteration 930, loss = 1.96525264
# Iteration 931, loss = 1.96456093
# Iteration 932, loss = 1.96452788
# Iteration 933, loss = 1.96311182
# Iteration 934, loss = 1.96290969
# Iteration 935, loss = 1.96244451
# Iteration 936, loss = 1.96113468
# Iteration 937, loss = 1.96078373
# Iteration 938, loss = 1.96066103
# Iteration 939, loss = 1.96043490
# Iteration 940, loss = 1.96032278
# Iteration 941, loss = 1.95874855
# Iteration 942, loss = 1.95822260
# Iteration 943, loss = 1.95726769
# Iteration 944, loss = 1.95674630
# Iteration 945, loss = 1.95593621
# Iteration 946, loss = 1.95566036
# Iteration 947, loss = 1.95551300
# Iteration 948, loss = 1.95436919
# Iteration 949, loss = 1.95334710
# Iteration 950, loss = 1.95326186
# Iteration 951, loss = 1.95235210
# Iteration 952, loss = 1.95259947
# Iteration 953, loss = 1.95185006
# Iteration 954, loss = 1.95094351
# Iteration 955, loss = 1.95105049
# Iteration 956, loss = 1.94939817
# Iteration 957, loss = 1.94941585
# Iteration 958, loss = 1.94833714
# Iteration 959, loss = 1.94880361
# Iteration 960, loss = 1.94818181
# Iteration 961, loss = 1.94684735
# Iteration 962, loss = 1.94649182
# Iteration 963, loss = 1.94568203
# Iteration 964, loss = 1.94471581
# Iteration 965, loss = 1.94409534
# Iteration 966, loss = 1.94362054
# Iteration 967, loss = 1.94340888
# Iteration 968, loss = 1.94196440
# Iteration 969, loss = 1.94205390
# Iteration 970, loss = 1.94169975
# Iteration 971, loss = 1.94064093
# Iteration 972, loss = 1.93998330
# Iteration 973, loss = 1.93946079
# Iteration 974, loss = 1.93914247
# Iteration 975, loss = 1.93906743
# Iteration 976, loss = 1.93747570
# Iteration 977, loss = 1.93726893
# Iteration 978, loss = 1.93596957
# Iteration 979, loss = 1.93588759
# Iteration 980, loss = 1.93550409
# Iteration 981, loss = 1.93465971
# Iteration 982, loss = 1.93394006
# Iteration 983, loss = 1.93345253
# Iteration 984, loss = 1.93294004
# Iteration 985, loss = 1.93244671
# Iteration 986, loss = 1.93186135
# Iteration 987, loss = 1.93158699
# Iteration 988, loss = 1.93100929
# Iteration 989, loss = 1.93086108
# Iteration 990, loss = 1.93022251
# Iteration 991, loss = 1.93042278
# Iteration 992, loss = 1.92789381
# Iteration 993, loss = 1.92744266
# Iteration 994, loss = 1.92712720
# Iteration 995, loss = 1.92609504
# Iteration 996, loss = 1.92477740
# Iteration 997, loss = 1.92407409
# Iteration 998, loss = 1.92370685
# Iteration 999, loss = 1.92316469
# Iteration 1000, loss = 1.92300502
